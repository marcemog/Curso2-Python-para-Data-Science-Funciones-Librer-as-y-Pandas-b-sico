# %% [markdown]
# # <font color=green> PYTHON PARA DATA SCIENCE - PANDAS
# ---

# %% [markdown]
# # <font color=green> 1. INTRODUCCIÓN A PYTHON
# ---

# %% [markdown]
# # 1.1 Introducción

# %% [markdown]
# > Python es un lenguaje de programación de alto nivel con soporte a múltiples paradigmas de programación. Es un proyecto *open source* y desde su aparición en 1991, viene convirtiéndose en uno de los lenguajes de programación interpretados más populares.
# >
# > En los últimos años Python ha desarrollado una comunidad activa de procesamiento científico y análisis de datos y viene destacándose como uno de los lenguajes más relevantes cuando el asunto es ciencia de datos y machine learning, tanto en el entorno académico como también en el entorno laboral.

# %% [markdown]
# # 1.2 Instalación y entorno de trabajo

# %% [markdown]
# ### Instalación Local
#
# ### https://www.python.org/downloads/
# ### o
# ### https://www.anaconda.com/distribution/

# %% [markdown]
# ### Google Colaboratory
#
# ### https://colab.research.google.com

# %% [markdown]
# ### Verificando versión

# %% [markdown]
# # 1.3 Trabajando con datos

# %%
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

# %%
dataset = pd.read_csv('db.csv', sep = ';')

# %%
dataset
# Out:
#                     Nombre                  Motor   Año  Kilometraje  Cero_km  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003      44410.0    False
# 1                   Passat           Motor Diesel  1991       5712.0    False
# 2                 Crossfox        Motor Diesel V8  1990      37123.0    False
# 3                      DS5        Motor 2.4 Turbo  2019          NaN     True
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006      25757.0    False
# ..                     ...                    ...   ...          ...      ...
# 253           Phantom 2013               Motor V8  2014      27505.0    False
# 254  Cadillac Ciel concept               Motor V8  1991      29981.0    False
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# 256       Aston Martin DB5           Motor Diesel  1996       7685.0    False
# 257                  Macan        Motor Diesel V6  1992      50188.0    False
#
#                                             Accesorios      Valor
# 0    ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# 1    ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# 2    ['Piloto automático', 'Control de estabilidad'...   72832.16
# 3    ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# 4    ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10
# ..                                                 ...        ...
# 253  ['Control de estabilidad', 'Piloto automático'...   51759.58
# 254  ['Asientos de cuero', 'Panel digital', 'Sensor...   51667.06
# 255  ['Llantas de aleación', 'Control de tracción',...   68934.03
# 256  ['Aire condicionado', '4 X 4', 'Transmisión au...  122110.90
# 257  ['Central multimedia', 'Techo panorámico', 'Ve...   90381.47
#
# [258 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# Nombre          object
# Motor           object
# Año              int64
# Kilometraje    float64
# Cero_km           bool
# Accesorios      object
# Valor          float64
# dtype: object

# %%
dataset[['Kilometraje','Valor']].describe()
# Out:
#          Kilometraje          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       258 non-null    object
#  1   Motor        258 non-null    object
#  2   Año          258 non-null    int64
#  3   Kilometraje  197 non-null    float64
#  4   Cero_km      258 non-null    bool
#  5   Accesorios   258 non-null    object
#  6   Valor        258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# # <font color=green> 2. TRABAJANDO CON TUPLAS
# ---

# %% [markdown]
# # 2.1 Creando tuplas
#
# Tuplas son secuencias **inmutables** que son utilizadas para guardar colecciones de objetos, geralmente heterogéneos. Pueden ser construídas de varias formas:
# ```
# - Utilizando un par de paréntesis: ( )
# - Utilizando una coma a la derecha: x,
# - Utilizando un par de paréntesis con objetos separados por comas: ( x, y, z )
# - Utilizando: tuple() o tuple(iterador)
# ```

# %%
()
# Out:
# ()

# %%
1, 2, 3
# Out:
# (1, 2, 3)

# %%
nombre = 'Passat'
valor = 153000
(nombre, valor)
# Out:
# ('Passat', 153000)

# %%
nombres_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nombres_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
type(nombres_carros)
# Out:
# tuple

# %% [markdown]
# # 2.2 Selecciones en tuplas

# %%
nombres_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nombres_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
nombres_carros[0]
# Out:
# 'Jetta Variant'

# %%
nombres_carros[1]
# Out:
# 'Passat'

# %%
nombres_carros[-1]
# Out:
# 'DS5'

# %%
nombres_carros[1:3]
# Out:
# ('Passat', 'Crossfox')

# %%
nombres_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))
nombres_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))

# %%
nombres_carros[-1]  #tupla dentro de tupla
# Out:
# ('Fusca', 'Gol', 'C4')

# %%
nombres_carros[-1][1]
# Out:
# 'Gol'

# %% [markdown]
# # 2.3 Iterando en tuplas

# %%
nombres_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nombres_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
for item in nombres_carros:
  print(item)
# Out:
# Jetta Variant
# Passat
# Crossfox
# DS5

# %% [markdown]
# ### Desempacando tuplas

# %%
nombres_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nombres_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
carro_1, carro_2, carro_3, carro_4 = nombres_carros

# %%
carro_1
# Out:
# 'Jetta Variant'

# %%
carro_2
# Out:
# 'Passat'

# %%
carro_3
# Out:
# 'Crossfox'

# %%
carro_4
# Out:
# 'DS5'

# %%
_, A, _, B = nombres_carros #con el _ hago que ignore el elemento de esa posicion de la tupla, en este caso solo guarda en A el elemento de la posicion 2 y en B el elemento de la posicion 4

# %%
A
# Out:
# 'Passat'

# %%
B
# Out:
# 'DS5'

# %%
_, C, *_ = nombres_carros #con el * antes del _ hago que se ignoren los elementos de esa posicion en adelante

# %%
C
# Out:
# 'Passat'

# %% [markdown]
# ## *zip()*
#
# https://docs.python.org/3.6/library/functions.html#zip

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
valores = [88078.64, 106161.94, 72832.16, 124549.07]
valores
# Out:
# [88078.64, 106161.94, 72832.16, 124549.07]

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64),
#  ('Passat', 106161.94),
#  ('Crossfox', 72832.16),
#  ('DS5', 124549.07)]

# %%
for item in zip(carros, valores):
  print(item)
# Out:
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.94)
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)

# %%
for carro, valor in zip(carros, valores):
  print(carro, valor)
# Out:
# Jetta Variant 88078.64
# Passat 106161.94
# Crossfox 72832.16
# DS5 124549.07

# %%
for carro, valor in zip(carros, valores):
  if valor > 100000:
    print(carro)
# Out:
# Passat
# DS5

# %% [markdown]
# # <font color=green> 3. TRABAJANDO CON DICCIONARIOS
# ---

# %% [markdown]
# # 3.1 Creando diccionarios
#
# Listas son colecciones secuenciales, es decir, los elementos de estas secuencias están ordenados y utilizan índices (números enteros) para acceder a los valores.
#
# Los diccionarios son colecciones ligeramente diferentes. Son estructuras de datos que representan un tipo de mapeo. Los mapeos son colecciones de asociaciones entre pares de valores donde el primer elemento del par se conoce como llave (*key*) y el segundo como valor (*value*).
#
# ```
# diccionario = {key_1: value_1, key_2: value_2, ..., key_n: value_n}
# ```
#
# https://docs.python.org/3.6/library/stdtypes.html#typesmapping

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
valores = [88078.64, 106161.94, 72832.16]
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
carros.index('Passat')
# Out:
# 1

# %%
valores[carros.index('Passat')]
# Out:
# 106161.94

# %%
datos = {'Jetta Variant':88078.64 , 'Passat':106161.94, 'Crossfox':72832.16}
datos
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
type(datos)
# Out:
# dict

# %% [markdown]
# ### Creando diccionarios con *zip()*

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64), ('Passat', 106161.94), ('Crossfox', 72832.16)]

# %%
datos = dict(zip(carros, valores))
datos
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %% [markdown]
# # 3.2 Operaciones con diccionarios

# %% [markdown]
# ## *dict[ key ]*
#
# Devuelve el valor correspondiente a la llave (*key*) en el diccionario.

# %%
datos['Passat']
# Out:
# 106161.94

# %% [markdown]
# ## *key in dict*
#
# Devuelve **True** si la llave (*key*) es encontrada en el diccionario.

# %%
'Passat' in datos
# Out:
# True

# %%
'Fusca' in datos
# Out:
# False

# %%
'Fusca' not in datos
# Out:
# True

# %% [markdown]
# ## *len(dict)*
#
# Devuelve el número de itens del diccionario.

# %%
len(datos)
# Out:
# 3

# %% [markdown]
# ## *dict[ key ] = value*
#
# Incluye un item al diccionario.

# %%
datos['DS5'] = 123456.43

# %%
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'Crossfox': 72832.16,
#  'DS5': 123456.43}

# %% [markdown]
# ## *del dict[ key ]*
#
# Borra el item de llave (*key*) del diccionario.

# %%
del datos['Passat']

# %%
datos
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16, 'DS5': 123456.43}

# %% [markdown]
# # 3.3 Métodos de diccionarios

# %% [markdown]
# ## *dict.update()*
#
# Actualiza el diccionario.

# %%
datos
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16, 'DS5': 123456.43}

# %%
datos.update({'Passat':106161.94})
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'DS5': 123456.43,
#  'Passat': 106161.94}

# %%
datos.update({'Passat':106161.95, 'Fusca':150000})
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'DS5': 123456.43,
#  'Passat': 106161.95,
#  'Fusca': 150000}

# %% [markdown]
# ## *dict.copy()*
#
# Crea una copia del diccionario.

# %%
datosCopy = datos.copy()

# %%
datosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'DS5': 123456.43,
#  'Passat': 106161.95,
#  'Fusca': 150000}

# %%
del datosCopy['Fusca']
datosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'DS5': 123456.43,
#  'Passat': 106161.95}

# %%
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'DS5': 123456.43,
#  'Passat': 106161.95,
#  'Fusca': 150000}

# %% [markdown]
# ## *dict.pop(key[, default ])*
#
# Si la llave se encuentra en el diccionario, el elemento se elimina y se devuelve su valor. De lo contrario, se devuelve el valor especificado como *default*. Si no se proporciona el valor *default* y la llave no se encuentra en el diccionario, se generará un error.

# %%
datosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'DS5': 123456.43,
#  'Passat': 106161.95}

# %%
datosCopy.pop('Passat')
# Out:
# 106161.95

# %%
datosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16, 'DS5': 123456.43}

# %%
datosCopy.pop('Passat')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-6cf29ea99361> in <cell line: 1>()
# ----> 1 datosCopy.pop('Passat')
#
# KeyError: 'Passat'

# %%
datosCopy.pop('Passat', 'Llave no encontrada')
# Out:
# 'Llave no encontrada'

# %%
datosCopy.pop('DS5', 'Llave no encontrada')
# Out:
# 123456.43

# %%
datosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16}

# %% [markdown]
# ## *dict.clear()*
#
# Borra todos los itens del diccionario.

# %%
datosCopy.clear()

# %%
datosCopy
# Out:
# {}

# %% [markdown]
# # 3.4 Iterando en diccionarios

# %% [markdown]
# ## *dict.keys()*
#
# Devuelve una lista con las llaves (*keys*) del diccionario.

# %%
datos.keys()
# Out:
# dict_keys(['Jetta Variant', 'Crossfox', 'DS5', 'Passat', 'Fusca'])

# %%
for key in datos.keys():
  print (key)
# Out:
# Jetta Variant
# Crossfox
# DS5
# Passat
# Fusca

# %% [markdown]
# ## *dict.values()*
#
# Devuelve una lista con todos los valores (*values*) del diccionario.

# %%
datos.values()
# Out:
# dict_values([88078.64, 72832.16, 123456.43, 106161.95, 150000])

# %% [markdown]
# ## *dict.items()*
#
# Devuelve una lista con una tupla para cada par llave-valor (*key-value*) del diccionario.

# %%
datos.items()
# Out:
# dict_items([('Jetta Variant', 88078.64), ('Crossfox', 72832.16), ('DS5', 123456.43), ('Passat', 106161.95), ('Fusca', 150000)])

# %%
for item in datos.items():
  print(item)
# Out:
# ('Jetta Variant', 88078.64)
# ('Crossfox', 72832.16)
# ('DS5', 123456.43)
# ('Passat', 106161.95)
# ('Fusca', 150000)

# %%
for key, value in datos.items():
  print(key, '->', value)
# Out:
# Jetta Variant -> 88078.64
# Crossfox -> 72832.16
# DS5 -> 123456.43
# Passat -> 106161.95
# Fusca -> 150000

# %%
for key, value in datos.items():
  if value > 100000:
    print(key)
# Out:
# DS5
# Passat
# Fusca

# %% [markdown]
# # <font color=green> 4. FUNCIONES Y PAQUETES
# ---
#
# Funciones son unidades de código reutilizables que realizan una tarea específica, pueden recibir alguna entrada y también pueden devolver algún resultado.

# %% [markdown]
# # 4.1 Built-in function
#
# El lenguaje Python tiene varias funciones integradas que siempre están accesibles. Algunas ya las usamos en nuestro entrenamiento:
# type(), print(), zip(), len(), set() etc.
#
# https://docs.python.org/3.6/library/functions.html

# %%
datos = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
datos
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
valores = []
for valor in datos.values():
  valores.append(valor)
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
suma = 0
for valor in datos.values():
  suma += valor
suma
# Out:
# 267072.74

# %%
list(datos.values())
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
sum(datos.values())
# Out:
# 267072.74

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print?

# %% [markdown]
# # 4.2 Definiendo funciones sin y con parámetros

# %% [markdown]
# ### Funciones sin parámetros
#
# #### Formato estándar
#
# ```
# def <nombre>():
#     <instrucciones>
# ```

# %%
def media():
  valor = (1+2+3)/3
  print(valor)

# %%
media()
# Out:
# 2.0

# %% [markdown]
# ### Funciones con parámetros
#
# #### Formato estándar
#
# ```
# def <nombre>(<param_1>, <param_2>, ..., <param_n>):
#     <instrucciones>
# ```

# %%
def media(n1,n2,n3):
  valor = (n1+n2+n3)/3
  print(valor)

# %%
media(1,2,3)
# Out:
# 2.0

# %%
media(23,45,67)
# Out:
# 45.0

# %%
def media(lista):
  valor = sum(lista)/ len(lista)
  print(valor)

# %%
resultado = media([1,2,3,4,5,6,7,8])
# Out:
# 4.5

# %%
resultado

# %%
type(resultado)
# Out:
# NoneType

# %% [markdown]
# # 4.3 Definiendo funciones que devuelven valores

# %% [markdown]
# ### Funciones que devuelven un valor
#
# #### Formato estándar
#
# ```
# def <nombre>(<param_1>, <param_2>, ..., <param_n>):
#     <instrucciones>
#     return <resultado>
# ```

# %%
def media(lista):
  valor = sum(lista)/ len(lista)
  return (valor)

# %%
media([1,2,3,4,5,6,7,8])
# Out:
# 4.5

# %%
resultado = media([1,2,3,4,5,6,7,8])

# %%
resultado
# Out:
# 4.5

# %% [markdown]
# ### Funciones que devuelven más de un valor
#
# #### Formato estándar
#
# ```
# def <nombre>(<param_1>, <param_2>, ..., <param_n>):
#     <instrucciones>
#     return (<resultado_1>, <resultado_2>, ..., <resultado_n>)
# ```

# %%
def media(lista):
  valor = sum(lista)/ len(lista)
  return (valor, len(lista))

# %%
media([1,2,3,4,5,6,7,8])
# Out:
# (4.5, 8)

# %%
resultado, n = media([1,2,3,4,5,6,7,8])

# %%
resultado
# Out:
# 4.5

# %%
n
# Out:
# 8

# %% [markdown]
# # <font color=green> 5. PANDAS BÁSICO
# ---
#
# **versión: 1.1.0**
#
# Pandas es una herramienta de manipulación de datos de alto nivel, construida sobre la base del paquete Numpy. El paquete pandas tiene estructuras de datos muy interesantes para la manipulación de datos y, por esto, es ampliamente utilizado por los científicos de datos.
#
#
# ## Estructuras de Datos
#
# ### Series
#
# Series son arrays unidimensionales etiquetados capaces de almacenar cualquier tipo de dato. Las etiquetas de las líneas se denominan **index**. La forma básica de crear una Series es la siguiente:
#
#
# ```
#     s = pd.Series(datos, index = index)
# ```
#
# El argumento *datos* puede ser un diccionario, una lista, un array Numpy o una constante.
#
# ### DataFrames
#
# DataFrame es una estructura de datos tabular bidimensional con etiquetas de fila y columna. Como la Series, los DataFrames son capaces de almacenar cualquier tipo de datos.
#
#
# ```
#     df = pd.DataFrame(datos, index = index, columns = columns)
# ```
#
# El argumento *datos* puede ser un diccionario, una lista, un array Numpy, una Series y otro DataFrame.
#
# **Documentación:** https://pandas.pydata.org/pandas-docs/version/1.1.0/

# %% [markdown]
# # 5.1 Estructuras de datos

# %%
import pandas as pd

# %% [markdown]
# ### Creando una Series a partir de una lista

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
pd.Series(carros)
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %% [markdown]
# ### Creando un DataFrame a partir de una lista de diccionarios

# %%
datos = [
    {'Nombre': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Año': 2003, 'Kilometraje': 44410.0, 'Cero_km': False, 'Valor': 88078.64},
    {'Nombre': 'Passat', 'Motor': 'Motor Diesel', 'Año': 1991, 'Kilometraje': 5712.0, 'Cero_km': False, 'Valor': 106161.94},
    {'Nombre': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Año': 1990, 'Kilometraje': 37123.0, 'Cero_km': False, 'Valor': 72832.16}
]

# %%
dataset = pd.DataFrame(datos)

# %%
dataset
# Out:
#           Nombre            Motor   Año  Kilometraje  Cero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003      44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991       5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990      37123.0    False   72832.16

# %%
dataset[['Nombre','Año', 'Kilometraje', 'Motor', 'Cero_km', 'Valor']]
# Out:
#           Nombre   Año  Kilometraje            Motor  Cero_km      Valor
# 0  Jetta Variant  2003      44410.0  Motor 4.0 Turbo    False   88078.64
# 1         Passat  1991       5712.0     Motor Diesel    False  106161.94
# 2       Crossfox  1990      37123.0  Motor Diesel V8    False   72832.16

# %% [markdown]
# ### Creando un DataFrame a partir de un diccionario

# %%
datos = {
    'Nombre': ['Jetta Variant', 'Passat', 'Crossfox'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Año': [2003, 1991, 1990],
    'Kilometraje': [44410.0, 5712.0, 37123.0],
    'Cero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}

# %%
dataset = pd.DataFrame(datos)

# %%
dataset
# Out:
#           Nombre            Motor   Año  Kilometraje  Cero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003      44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991       5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990      37123.0    False   72832.16

# %% [markdown]
# ### Creando un DataFrame a partir de un archivo externo

# %%
dataset = pd.read_csv('db.csv', sep = ';', index_col = 0)

# %%
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# Nombre
# Jetta Variant          ['Llantas de aleación', 'Cerraduras electricas...
# Passat                 ['Central multimedia', 'Techo panorámico', 'Fr...
# Crossfox               ['Piloto automático', 'Control de estabilidad'...
# DS5                    ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# Aston Martin DB4       ['Llantas de aleación', '4 X 4', 'Central mult...
# ...                                                                  ...
# Phantom 2013           ['Control de estabilidad', 'Piloto automático'...
# Cadillac Ciel concept  ['Asientos de cuero', 'Panel digital', 'Sensor...
# Classe GLK             ['Llantas de aleación', 'Control de tracción',...
# Aston Martin DB5       ['Aire condicionado', '4 X 4', 'Transmisión au...
# Macan                  ['Central multimedia', 'Techo panorámico', 'Ve...
#
#                            Valor
# Nombre
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 6 columns]

# %% [markdown]
# # 5.2 Selecciones con DataFrames

# %% [markdown]
# ### Seleccionando columnas

# %%
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios      Valor
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox          ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10

# %%
dataset['Valor']
# Out:
# Nombre
# Jetta Variant             88078.64
# Passat                   106161.94
# Crossfox                  72832.16
# DS5                      124549.07
# Aston Martin DB4          92612.10
#                            ...
# Phantom 2013              51759.58
# Cadillac Ciel concept     51667.06
# Classe GLK                68934.03
# Aston Martin DB5         122110.90
# Macan                     90381.47
# Name: Valor, Length: 258, dtype: float64

# %%
type(dataset['Valor'])
# Out:
# pandas.core.series.Series

# %%
dataset[['Valor']]
# Out:
#                            Valor
# Nombre
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 1 columns]

# %%
type(dataset[['Valor']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Seleccionando lineas - [ i : j ]
#
# <font color=red>**Observación:**</font> La indexación tiene origen en cero y en las particiones(*slices*) la línea con índice i es **incluída** y la línea con índice j **no es incluída** en el resultado.

# %%
dataset[0:3]
# Out:
#                          Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant  Motor 4.0 Turbo  2003      44410.0    False
# Passat            Motor Diesel  1991       5712.0    False
# Crossfox       Motor Diesel V8  1990      37123.0    False
#
#                                                       Accesorios      Valor
# Nombre
# Jetta Variant  ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat         ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox       ['Piloto automático', 'Control de estabilidad'...   72832.16

# %% [markdown]
# ### Utilizando .loc para selecciones
#
# <font color=red>**Observación:**</font> Selecciona un grupo de líneas y columnas según las etiquetas o una matriz booleana.

# %%
dataset.loc['Passat'] #el resultado viene en formato de series porque tiene un par de corchetes, si quiero en data frame hay que poner doble par de corchetes
# Out:
# Motor                                               Motor Diesel
# Año                                                         1991
# Kilometraje                                               5712.0
# Cero_km                                                    False
# Accesorios     ['Central multimedia', 'Techo panorámico', 'Fr...
# Valor                                                  106161.94
# Name: Passat, dtype: object

# %%
dataset.loc[['Passat', 'DS5']] #al buscar con dos argumentos si o si hay que usar doble corchete para que salga en formato de data frame, de lo contraio al usar un solo par tira error
# Out:
#                   Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Passat     Motor Diesel  1991       5712.0    False
# DS5     Motor 2.4 Turbo  2019          NaN     True
#
#                                                Accesorios      Valor
# Nombre
# Passat  ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# DS5     ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07

# %%
dataset.loc[['Passat', 'DS5'],['Motor', 'Valor']]
# Out:
#                   Motor      Valor
# Nombre
# Passat     Motor Diesel  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %%
dataset.loc[:, ['Motor', 'Valor']]
# Out:
#                                        Motor      Valor
# Nombre
# Jetta Variant                Motor 4.0 Turbo   88078.64
# Passat                          Motor Diesel  106161.94
# Crossfox                     Motor Diesel V8   72832.16
# DS5                          Motor 2.4 Turbo  124549.07
# Aston Martin DB4             Motor 2.4 Turbo   92612.10
# ...                                      ...        ...
# Phantom 2013                        Motor V8   51759.58
# Cadillac Ciel concept               Motor V8   51667.06
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03
# Aston Martin DB5                Motor Diesel  122110.90
# Macan                        Motor Diesel V6   90381.47
#
# [258 rows x 2 columns]

# %% [markdown]
# ### Utilizando .iloc para selecciones
#
# <font color=red>**Observación:**</font> Selecciona con base en los índices, es decir, utiliza la posición de las informaciones.

# %%
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios      Valor
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox          ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10

# %%
dataset.iloc[[1]]
# Out:
#                Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Passat  Motor Diesel  1991       5712.0    False
#
#                                                Accesorios      Valor
# Nombre
# Passat  ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94

# %%
dataset.iloc[1:4] #al usar un intervalo va con un solo par de corchetes
# Out:
#                     Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Passat       Motor Diesel  1991       5712.0    False
# Crossfox  Motor Diesel V8  1990      37123.0    False
# DS5       Motor 2.4 Turbo  2019          NaN     True
#
#                                                  Accesorios      Valor
# Nombre
# Passat    ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox  ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5       ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07

# %%
dataset.iloc[1:4, [0, 5, 2]]
# Out:
#                     Motor      Valor  Kilometraje
# Nombre
# Passat       Motor Diesel  106161.94       5712.0
# Crossfox  Motor Diesel V8   72832.16      37123.0
# DS5       Motor 2.4 Turbo  124549.07          NaN

# %%
dataset.iloc[[1, 42, 22], [0, 5, 2]]
# Out:
#                                Motor      Valor  Kilometraje
# Nombre
# Passat                  Motor Diesel  106161.94       5712.0
# Optima                 Motor 1.8 16v   86641.34          NaN
# Lamborghini Obvious  Motor Diesel V6  133529.84      98079.0

# %%
dataset.iloc[:, [0, 5, 2]]
# Out:
#                                        Motor      Valor  Kilometraje
# Nombre
# Jetta Variant                Motor 4.0 Turbo   88078.64      44410.0
# Passat                          Motor Diesel  106161.94       5712.0
# Crossfox                     Motor Diesel V8   72832.16      37123.0
# DS5                          Motor 2.4 Turbo  124549.07          NaN
# Aston Martin DB4             Motor 2.4 Turbo   92612.10      25757.0
# ...                                      ...        ...          ...
# Phantom 2013                        Motor V8   51759.58      27505.0
# Cadillac Ciel concept               Motor V8   51667.06      29981.0
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03      52637.0
# Aston Martin DB5                Motor Diesel  122110.90       7685.0
# Macan                        Motor Diesel V6   90381.47      50188.0
#
# [258 rows x 3 columns]

# %% [markdown]
# # 5.3 Consultas en DataFrames

# %%
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios      Valor
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox          ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10

# %%
dataset.Motor
# Out:
# Nombre
# Jetta Variant                  Motor 4.0 Turbo
# Passat                            Motor Diesel
# Crossfox                       Motor Diesel V8
# DS5                            Motor 2.4 Turbo
# Aston Martin DB4               Motor 2.4 Turbo
#                                  ...
# Phantom 2013                          Motor V8
# Cadillac Ciel concept                 Motor V8
# Classe GLK               Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                  Motor Diesel
# Macan                          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
dataset.Motor == 'Motor Diesel'
# Out:
# Nombre
# Jetta Variant            False
# Passat                    True
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5          True
# Macan                    False
# Name: Motor, Length: 258, dtype: bool

# %%
type(dataset.Motor == 'Motor Diesel')
# Out:
# pandas.core.series.Series

# %%
dataset[dataset.Motor == 'Motor Diesel']
# Out:
#                               Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Passat                 Motor Diesel  1991       5712.0    False
# Effa Hafei Picape Baú  Motor Diesel  1991     102959.0    False
# Sorento                Motor Diesel  2019          NaN     True
# New Fiesta Hatch       Motor Diesel  2017     118895.0    False
# Kangoo Express         Motor Diesel  2007      29132.0    False
# Fit                    Motor Diesel  2013      44329.0    False
# Cielo Hatch            Motor Diesel  2019          NaN     True
# Symbol                 Motor Diesel  2016     117714.0    False
# A4 Sedan               Motor Diesel  2002      30511.0    False
# A4 Avant               Motor Diesel  2014      17357.0    False
# Silver Shadow          Motor Diesel  2015      99052.0    False
# Camry                  Motor Diesel  2019          NaN     True
# Clio                   Motor Diesel  1990      66437.0    False
# Série 3 M3 Coupé       Motor Diesel  2013      19896.0    False
# Gallardo LP 560 – 4    Motor Diesel  2000     113045.0    False
# Chana Utility          Motor Diesel  2009      52034.0    False
# TT Roadster            Motor Diesel  1998     107392.0    False
# Aston Martin Virage    Motor Diesel  2019          NaN     True
# Sandero                Motor Diesel  2015      34783.0    False
# XKR                    Motor Diesel  1996      85127.0    False
# X5                     Motor Diesel  2002      13606.0    False
# Dodge Dakota           Motor Diesel  1993      71544.0    False
# i30 CW                 Motor Diesel  2015       8497.0    False
# Série 7 Sedã           Motor Diesel  2019          NaN     True
# V60                    Motor Diesel  2004      91840.0    False
# Aston Martin DB5       Motor Diesel  1996       7685.0    False
#
#                                                               Accesorios  \
# Nombre
# Passat                 ['Central multimedia', 'Techo panorámico', 'Fr...
# Effa Hafei Picape Baú  ['Control de estabilidad', 'Panel digital', 'V...
# Sorento                ['Sensor de lluvia', 'Cámara de estacionamient...
# New Fiesta Hatch       ['Sensor de estacionamiento', 'Cerraduras elec...
# Kangoo Express         ['Asientos de cuero', 'Transmisión automática'...
# Fit                    ['Frenos ABS', 'Cámara de estacionamiento', 'T...
# Cielo Hatch            ['Panel digital', 'Central multimedia', 'Cámar...
# Symbol                 ['4 X 4', 'Piloto automático', 'Sensor crepusc...
# A4 Sedan               ['Cámara de estacionamiento', '4 X 4', 'Cerrad...
# A4 Avant               ['Techo panorámico', '4 X 4', 'Asientos de cue...
# Silver Shadow          ['4 X 4', 'Central multimedia', 'Aire condicio...
# Camry                  ['Cerraduras electricas', 'Llantas de aleación...
# Clio                   ['4 X 4', 'Transmisión automática', 'Frenos AB...
# Série 3 M3 Coupé       ['Asientos de cuero', 'Sensor de lluvia', 'Air...
# Gallardo LP 560 – 4    ['Frenos ABS', 'Techo panorámico', 'Central mu...
# Chana Utility          ['Aire condicionado', 'Sensor de estacionamien...
# TT Roadster            ['Aire condicionado', 'Sensor de estacionamien...
# Aston Martin Virage    ['Cerraduras electricas', 'Control de tracción...
# Sandero                ['Piloto automático', 'Techo panorámico', 'Tra...
# XKR                    ['Control de tracción', 'Aire condicionado', '...
# X5                     ['Control de tracción', 'Piloto automático', '...
# Dodge Dakota           ['Control de tracción', 'Sensor de estacionami...
# i30 CW                 ['Sensor de lluvia', 'Ventanas eléctricas', 'C...
# Série 7 Sedã           ['Ventanas eléctricas', 'Cerraduras electricas...
# V60                    ['Llantas de aleación', 'Sensor crepuscular', ...
# Aston Martin DB5       ['Aire condicionado', '4 X 4', 'Transmisión au...
#
#                            Valor
# Nombre
# Passat                 106161.94
# Effa Hafei Picape Baú  125684.65
# Sorento                 81399.35
# New Fiesta Hatch        66007.16
# Kangoo Express         146716.91
# Fit                     77836.23
# Cielo Hatch            145197.70
# Symbol                 133030.60
# A4 Sedan                96369.04
# A4 Avant               138946.88
# Silver Shadow          143568.22
# Camry                  138597.27
# Clio                   111130.33
# Série 3 M3 Coupé        69219.89
# Gallardo LP 560 – 4    144118.91
# Chana Utility          132662.32
# TT Roadster             85311.40
# Aston Martin Virage     97290.18
# Sandero                112350.61
# XKR                     54263.16
# X5                      62041.32
# Dodge Dakota           141083.35
# i30 CW                  73311.75
# Série 7 Sedã            67539.79
# V60                    114728.74
# Aston Martin DB5       122110.90

# %%
dataset[(dataset.Motor == 'Motor Diesel') & (dataset.Cero_km	== True)]
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Sorento              Motor Diesel  2019          NaN     True
# Cielo Hatch          Motor Diesel  2019          NaN     True
# Camry                Motor Diesel  2019          NaN     True
# Aston Martin Virage  Motor Diesel  2019          NaN     True
# Série 7 Sedã         Motor Diesel  2019          NaN     True
#
#                                                             Accesorios  \
# Nombre
# Sorento              ['Sensor de lluvia', 'Cámara de estacionamient...
# Cielo Hatch          ['Panel digital', 'Central multimedia', 'Cámar...
# Camry                ['Cerraduras electricas', 'Llantas de aleación...
# Aston Martin Virage  ['Cerraduras electricas', 'Control de tracción...
# Série 7 Sedã         ['Ventanas eléctricas', 'Cerraduras electricas...
#
#                          Valor
# Nombre
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# Aston Martin Virage   97290.18
# Série 7 Sedã          67539.79

# %% [markdown]
# ### Utilizando el método query

# %%
dataset.query('Motor == "Motor Diesel" and Cero_km == True')
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Sorento              Motor Diesel  2019          NaN     True
# Cielo Hatch          Motor Diesel  2019          NaN     True
# Camry                Motor Diesel  2019          NaN     True
# Aston Martin Virage  Motor Diesel  2019          NaN     True
# Série 7 Sedã         Motor Diesel  2019          NaN     True
#
#                                                             Accesorios  \
# Nombre
# Sorento              ['Sensor de lluvia', 'Cámara de estacionamient...
# Cielo Hatch          ['Panel digital', 'Central multimedia', 'Cámar...
# Camry                ['Cerraduras electricas', 'Llantas de aleación...
# Aston Martin Virage  ['Cerraduras electricas', 'Control de tracción...
# Série 7 Sedã         ['Ventanas eléctricas', 'Cerraduras electricas...
#
#                          Valor
# Nombre
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# Aston Martin Virage   97290.18
# Série 7 Sedã          67539.79

# %% [markdown]
# # 5.4 Iterando con DataFrames

# %%
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios      Valor
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox          ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10

# %%
for item in dataset:
  print(item)
# Out:
# Motor
# Año
# Kilometraje
# Cero_km
# Accesorios
# Valor

# %%
list(dataset.iterrows())
# Out:
# [('Jetta Variant',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2003
#   Kilometraje                                              44410.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Cerraduras electricas...
#   Valor                                                   88078.64
#   Name: Jetta Variant, dtype: object),
#  ('Passat',
#   Motor                                               Motor Diesel
#   Año                                                         1991
#   Kilometraje                                               5712.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', 'Techo panorámico', 'Fr...
#   Valor                                                  106161.94
#   Name: Passat, dtype: object),
#  ('Crossfox',
#   Motor                                            Motor Diesel V8
#   Año                                                         1990
#   Kilometraje                                              37123.0
#   Cero_km                                                    False
#   Accesorios     ['Piloto automático', 'Control de estabilidad'...
#   Valor                                                   72832.16
#   Name: Crossfox, dtype: object),
#  ('DS5',
#   Motor                                            Motor 2.4 Turbo
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Cerraduras electricas', '4 X 4', 'Ventanas e...
#   Valor                                                  124549.07
#   Name: DS5, dtype: object),
#  ('Aston Martin DB4',
#   Motor                                            Motor 2.4 Turbo
#   Año                                                         2006
#   Kilometraje                                              25757.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', '4 X 4', 'Central mult...
#   Valor                                                    92612.1
#   Name: Aston Martin DB4, dtype: object),
#  ('Palio Weekend',
#   Motor                                              Motor 1.8 16v
#   Año                                                         2012
#   Kilometraje                                              10728.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de estacionamiento', 'Techo panorámic...
#   Valor                                                   97497.73
#   Name: Palio Weekend, dtype: object),
#  ('A5',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Transmisión automática', 'Cámara de estacion...
#   Valor                                                    56445.2
#   Name: A5, dtype: object),
#  ('Série 3 Cabrio',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2009
#   Kilometraje                                              77599.0
#   Cero_km                                                    False
#   Accesorios     ['Control de estabilidad', 'Sensor crepuscular...
#   Valor                                                  112310.44
#   Name: Série 3 Cabrio, dtype: object),
#  ('Dodge Jorney',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2010
#   Kilometraje                                              99197.0
#   Cero_km                                                    False
#   Accesorios     ['Ventanas eléctricas', 'Piloto automático', '...
#   Valor                                                  120716.27
#   Name: Dodge Jorney, dtype: object),
#  ('Carens',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         2011
#   Kilometraje                                              37978.0
#   Cero_km                                                    False
#   Accesorios     ['Aire condicionado', 'Panel digital', 'Centra...
#   Valor                                                   76566.49
#   Name: Carens, dtype: object),
#  ('Ford Edge',
#   Motor                                            Motor Diesel V6
#   Año                                                         2002
#   Kilometraje                                              12859.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor crepuscular', 'Llantas de aleación', ...
#   Valor                                                   71647.59
#   Name: Ford Edge, dtype: object),
#  ('Courier',
#   Motor                                            Motor Diesel V8
#   Año                                                         2007
#   Kilometraje                                               8052.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', '4 X 4', 'Piloto automá...
#   Valor                                                   73919.53
#   Name: Courier, dtype: object),
#  ('S-18',
#   Motor                                                   Motor V6
#   Año                                                         2001
#   Kilometraje                                              89773.0
#   Cero_km                                                    False
#   Accesorios     ['Asientos de cuero', 'Sensor de lluvia', 'Lla...
#   Valor                                                  112732.99
#   Name: S-18, dtype: object),
#  ('J5',
#   Motor                                                   Motor V6
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Sensor crepuscular', 'Panel digital', 'Llant...
#   Valor                                                   53183.38
#   Name: J5, dtype: object),
#  ('F-Type Coupé',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         2009
#   Kilometraje                                              41457.0
#   Cero_km                                                    False
#   Accesorios     ['Piloto automático', 'Sensor crepuscular', 'S...
#   Valor                                                  127488.42
#   Name: F-Type Coupé, dtype: object),
#  ('RAM',
#   Motor                                            Motor Diesel V8
#   Año                                                         2016
#   Kilometraje                                             115607.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor crepuscular', 'Transmisión automática...
#   Valor                                                    59910.4
#   Name: RAM, dtype: object),
#  ('Série 1',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2012
#   Kilometraje                                              46449.0
#   Cero_km                                                    False
#   Accesorios     ['Techo panorámico', 'Cámara de estacionamient...
#   Valor                                                   61118.59
#   Name: Série 1, dtype: object),
#  ('A3',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['4 X 4', 'Piloto automático', 'Central multim...
#   Valor                                                   88552.39
#   Name: A3, dtype: object),
#  ('XC90',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2016
#   Kilometraje                                              37086.0
#   Cero_km                                                    False
#   Accesorios     ['Cerraduras electricas', 'Ventanas eléctricas...
#   Valor                                                   62696.69
#   Name: XC90, dtype: object),
#  ('RS 3 Sportback',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2017
#   Kilometraje                                              15173.0
#   Cero_km                                                    False
#   Accesorios     ['4 X 4', 'Piloto automático', 'Central multim...
#   Valor                                                   101726.3
#   Name: RS 3 Sportback, dtype: object),
#  ('Pajero Sport',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2002
#   Kilometraje                                             101193.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de estacionamiento', 'Piloto automáti...
#   Valor                                                  106147.38
#   Name: Pajero Sport, dtype: object),
#  ('Série 1 M',
#   Motor                                                   Motor V8
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Control de estabilidad', 'Central multimedia...
#   Valor                                                    94564.4
#   Name: Série 1 M, dtype: object),
#  ('Lamborghini Obvious',
#   Motor                                            Motor Diesel V6
#   Año                                                         1994
#   Kilometraje                                              98079.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Transmisión automátic...
#   Valor                                                  133529.84
#   Name: Lamborghini Obvious, dtype: object),
#  ('Effa Hafei Picape Baú',
#   Motor                                               Motor Diesel
#   Año                                                         1991
#   Kilometraje                                             102959.0
#   Cero_km                                                    False
#   Accesorios     ['Control de estabilidad', 'Panel digital', 'V...
#   Valor                                                  125684.65
#   Name: Effa Hafei Picape Baú, dtype: object),
#  ('Lamborghini Murciélago',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Frenos ABS', 'Transmisión automática', 'Aire...
#   Valor                                                  121596.21
#   Name: Lamborghini Murciélago, dtype: object),
#  ('Up!',
#   Motor                                            Motor Diesel V6
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Sensor de estacionamiento', 'Ventanas eléctr...
#   Valor                                                    71367.1
#   Name: Up!, dtype: object),
#  ('Fiesta Rocam Sedan',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2016
#   Kilometraje                                               5795.0
#   Cero_km                                                    False
#   Accesorios     ['Aire condicionado', 'Asientos de cuero', 'Tr...
#   Valor                                                   95347.75
#   Name: Fiesta Rocam Sedan, dtype: object),
#  ('Sandero Stepway',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Frenos ABS', 'Aire condicionado', 'Techo pan...
#   Valor                                                  105432.84
#   Name: Sandero Stepway, dtype: object),
#  ('Cayman S',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2002
#   Kilometraje                                              58848.0
#   Cero_km                                                    False
#   Accesorios     ['Transmisión automática', 'Sensor de estacion...
#   Valor                                                   57045.27
#   Name: Cayman S, dtype: object),
#  ('V40',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         1991
#   Kilometraje                                              94381.0
#   Cero_km                                                    False
#   Accesorios     ['Cámara de estacionamiento', 'Sensor de estac...
#   Valor                                                   120432.7
#   Name: V40, dtype: object),
#  ('Classe SLS AMG',
#   Motor                                               Motor 1.0 8v
#   Año                                                         1997
#   Kilometraje                                              30163.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de estacionamiento', 'Control de esta...
#   Valor                                                    70707.2
#   Name: Classe SLS AMG, dtype: object),
#  ('Gol G4',
#   Motor                                              Motor 2.0 16v
#   Año                                                         1995
#   Kilometraje                                              53332.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor crepuscular', '4 X 4', 'Ventanas eléc...
#   Valor                                                   69105.18
#   Name: Gol G4, dtype: object),
#  ('Linea',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2018
#   Kilometraje                                              17720.0
#   Cero_km                                                    False
#   Accesorios     ['Piloto automático', 'Panel digital', 'Ventan...
#   Valor                                                   59358.69
#   Name: Linea, dtype: object),
#  ('Ford F100',
#   Motor                                              Motor 2.0 16v
#   Año                                                         1991
#   Kilometraje                                              33808.0
#   Cero_km                                                    False
#   Accesorios     ['Control de tracción', 'Sensor crepuscular', ...
#   Valor                                                    65955.4
#   Name: Ford F100, dtype: object),
#  ('J2',
#   Motor                                                   Motor V8
#   Año                                                         2014
#   Kilometraje                                              90684.0
#   Cero_km                                                    False
#   Accesorios     ['Techo panorámico', 'Sensor de estacionamient...
#   Valor                                                   60017.03
#   Name: J2, dtype: object),
#  ('Aston Martin DBS',
#   Motor                                                   Motor V8
#   Año                                                         1995
#   Kilometraje                                              43975.0
#   Cero_km                                                    False
#   Accesorios     ['Techo panorámico', 'Piloto automático', 'Air...
#   Valor                                                  118909.52
#   Name: Aston Martin DBS, dtype: object),
#  ('Pajero TR4',
#   Motor                                            Motor 2.4 Turbo
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Control de tracción', 'Asientos de cuero', '...
#   Valor                                                   51606.59
#   Name: Pajero TR4, dtype: object),
#  ('Polo Sedan',
#   Motor                                                   Motor V6
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Sensor de lluvia', 'Sensor crepuscular', 'Ai...
#   Valor                                                  123281.87
#   Name: Polo Sedan, dtype: object),
#  ('California',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2009
#   Kilometraje                                               5526.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Aire condicionado', '...
#   Valor                                                   69770.18
#   Name: California, dtype: object),
#  ('S60',
#   Motor                                            Motor 2.4 Turbo
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Techo panorámico', 'Frenos ABS', '4 X 4', 'A...
#   Valor                                                  102609.54
#   Name: S60, dtype: object),
#  ('Tucson',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2013
#   Kilometraje                                              93415.0
#   Cero_km                                                    False
#   Accesorios     ['Ventanas eléctricas', 'Sensor crepuscular', ...
#   Valor                                                   67997.19
#   Name: Tucson, dtype: object),
#  ('HB20',
#   Motor                                                   Motor V6
#   Año                                                         2003
#   Kilometraje                                              40762.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Cerraduras electricas', ...
#   Valor                                                  135235.29
#   Name: HB20, dtype: object),
#  ('Optima',
#   Motor                                              Motor 1.8 16v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Central multimedia', 'Aire condicionado', 'T...
#   Valor                                                   86641.34
#   Name: Optima, dtype: object),
#  ('Logan',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2002
#   Kilometraje                                              86302.0
#   Cero_km                                                    False
#   Accesorios     ['Cámara de estacionamiento', 'Ventanas eléctr...
#   Valor                                                  136818.39
#   Name: Logan, dtype: object),
#  ('Range Rover Vogue',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['4 X 4', 'Ventanas eléctricas', 'Llantas de a...
#   Valor                                                  117626.73
#   Name: Range Rover Vogue, dtype: object),
#  ('Sonata',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         2002
#   Kilometraje                                               9755.0
#   Cero_km                                                    False
#   Accesorios     ['Piloto automático', 'Aire condicionado', 'Ve...
#   Valor                                                    56208.7
#   Name: Sonata, dtype: object),
#  ('Ford New Fiesta Sedan',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2004
#   Kilometraje                                              69945.0
#   Cero_km                                                    False
#   Accesorios     ['Techo panorámico', 'Panel digital', 'Aire co...
#   Valor                                                   84222.65
#   Name: Ford New Fiesta Sedan, dtype: object),
#  ('Série 5 Gran Turismo',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2001
#   Kilometraje                                               2395.0
#   Cero_km                                                    False
#   Accesorios     ['Control de tracción', 'Piloto automático', '...
#   Valor                                                   90781.65
#   Name: Série 5 Gran Turismo, dtype: object),
#  ('CR-V',
#   Motor                                            Motor Diesel V8
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Transmisión automática', 'Central multimedia...
#   Valor                                                    64701.1
#   Name: CR-V, dtype: object),
#  ('Ford EcoSport',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2003
#   Kilometraje                                              80349.0
#   Cero_km                                                    False
#   Accesorios     ['Ventanas eléctricas', 'Piloto automático', '...
#   Valor                                                  126350.49
#   Name: Ford EcoSport, dtype: object),
#  ('Versa',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2009
#   Kilometraje                                              85554.0
#   Cero_km                                                    False
#   Accesorios     ['Asientos de cuero', 'Aire condicionado', 'Ll...
#   Valor                                                  148152.89
#   Name: Versa, dtype: object),
#  ('Classe E',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2006
#   Kilometraje                                              50496.0
#   Cero_km                                                    False
#   Accesorios     ['Frenos ABS', 'Sensor de estacionamiento', 'C...
#   Valor                                                  132298.83
#   Name: Classe E, dtype: object),
#  ('Carnival',
#   Motor                                                   Motor V8
#   Año                                                         2000
#   Kilometraje                                              67716.0
#   Cero_km                                                    False
#   Accesorios     ['Cerraduras electricas', 'Transmisión automát...
#   Valor                                                  137627.63
#   Name: Carnival, dtype: object),
#  ('Aston Martin V8 Vantage Roadster',
#   Motor                                            Motor 2.4 Turbo
#   Año                                                         2006
#   Kilometraje                                              93947.0
#   Cero_km                                                    False
#   Accesorios     ['Transmisión automática', 'Cámara de estacion...
#   Valor                                                   80422.71
#   Name: Aston Martin V8 Vantage Roadster, dtype: object),
#  ('Hoggar',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         2010
#   Kilometraje                                              35345.0
#   Cero_km                                                    False
#   Accesorios     ['Control de estabilidad', 'Asientos de cuero'...
#   Valor                                                   56373.99
#   Name: Hoggar, dtype: object),
#  ('A1',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         1994
#   Kilometraje                                              81007.0
#   Cero_km                                                    False
#   Accesorios     ['Panel digital', 'Transmisión automática', 'C...
#   Valor                                                   70846.03
#   Name: A1, dtype: object),
#  ('Aston Martin DB7 Vantage',
#   Motor                                                   Motor V6
#   Año                                                         2007
#   Kilometraje                                             119513.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor crepuscular', 'Piloto automático', 'T...
#   Valor                                                  128694.23
#   Name: Aston Martin DB7 Vantage, dtype: object),
#  ('CLA',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Central multimedia', 'Sensor de lluvia', 'Co...
#   Valor                                                  133329.19
#   Name: CLA, dtype: object),
#  ('Accord',
#   Motor                                                   Motor V8
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Sensor de estacionamiento', 'Aire condiciona...
#   Valor                                                  131961.43
#   Name: Accord, dtype: object),
#  ('EXTRA 103EX',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Sensor de estacionamiento', 'Central multime...
#   Valor                                                  112033.27
#   Name: EXTRA 103EX, dtype: object),
#  ('Sorento',
#   Motor                                               Motor Diesel
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Sensor de lluvia', 'Cámara de estacionamient...
#   Valor                                                   81399.35
#   Name: Sorento, dtype: object),
#  ('Tiggo',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Cámara de estacionamiento', 'Frenos ABS', 'P...
#   Valor                                                    97163.1
#   Name: Tiggo, dtype: object),
#  ('New Fiesta Hatch',
#   Motor                                               Motor Diesel
#   Año                                                         2017
#   Kilometraje                                             118895.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de estacionamiento', 'Cerraduras elec...
#   Valor                                                   66007.16
#   Name: New Fiesta Hatch, dtype: object),
#  ('Jeep Renegade',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         2011
#   Kilometraje                                              48509.0
#   Cero_km                                                    False
#   Accesorios     ['Ventanas eléctricas', 'Techo panorámico', 'A...
#   Valor                                                  128776.22
#   Name: Jeep Renegade, dtype: object),
#  ('Lamborghini Ankonian',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2001
#   Kilometraje                                             100912.0
#   Cero_km                                                    False
#   Accesorios     ['Asientos de cuero', 'Cámara de estacionamien...
#   Valor                                                  142623.02
#   Name: Lamborghini Ankonian, dtype: object),
#  ('Space Cross',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         1996
#   Kilometraje                                              95649.0
#   Cero_km                                                    False
#   Accesorios     ['Techo panorámico', 'Ventanas eléctricas', 'S...
#   Valor                                                  136930.13
#   Name: Space Cross, dtype: object),
#  ('Touareg',
#   Motor                                                   Motor V8
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Control de estabilidad', 'Piloto automático'...
#   Valor                                                   66526.61
#   Name: Touareg, dtype: object),
#  ('Classe M',
#   Motor                                               Motor 1.0 8v
#   Año                                                         1994
#   Kilometraje                                              90495.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', 'Asientos de cuero', 'L...
#   Valor                                                  114154.87
#   Name: Classe M, dtype: object),
#  ('Lancer Evolution X',
#   Motor                                            Motor Diesel V6
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Ventanas eléctricas', 'Transmisión automátic...
#   Valor                                                  142392.75
#   Name: Lancer Evolution X, dtype: object),
#  ('Kangoo Express',
#   Motor                                               Motor Diesel
#   Año                                                         2007
#   Kilometraje                                              29132.0
#   Cero_km                                                    False
#   Accesorios     ['Asientos de cuero', 'Transmisión automática'...
#   Valor                                                  146716.91
#   Name: Kangoo Express, dtype: object),
#  ('SW4',
#   Motor                                            Motor Diesel V6
#   Año                                                         1994
#   Kilometraje                                              23802.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Asientos de cuero', 'Con...
#   Valor                                                  122485.68
#   Name: SW4, dtype: object),
#  ('Cadillac ELR',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2007
#   Kilometraje                                              84992.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor crepuscular', 'Cerraduras electricas'...
#   Valor                                                   97951.03
#   Name: Cadillac ELR, dtype: object),
#  ('Doblò',
#   Motor                                              Motor 1.8 16v
#   Año                                                         1997
#   Kilometraje                                              54395.0
#   Cero_km                                                    False
#   Accesorios     ['Cámara de estacionamiento', 'Techo panorámic...
#   Valor                                                   78283.49
#   Name: Doblò, dtype: object),
#  ('Lamborghini Egoista',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2006
#   Kilometraje                                              26731.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Control de tracción',...
#   Valor                                                   83434.04
#   Name: Lamborghini Egoista, dtype: object),
#  ('Fit',
#   Motor                                               Motor Diesel
#   Año                                                         2013
#   Kilometraje                                              44329.0
#   Cero_km                                                    False
#   Accesorios     ['Frenos ABS', 'Cámara de estacionamiento', 'T...
#   Valor                                                   77836.23
#   Name: Fit, dtype: object),
#  ('C5',
#   Motor                                              Motor 2.0 16v
#   Año                                                         1994
#   Kilometraje                                             118236.0
#   Cero_km                                                    False
#   Accesorios     ['Panel digital', 'Techo panorámico', 'Piloto ...
#   Valor                                                   60813.92
#   Name: C5, dtype: object),
#  ('Celer Hatch',
#   Motor                                                   Motor V8
#   Año                                                         2008
#   Kilometraje                                             113808.0
#   Cero_km                                                    False
#   Accesorios     ['Control de estabilidad', 'Transmisión automá...
#   Valor                                                   91353.86
#   Name: Celer Hatch, dtype: object),
#  ('HB20S',
#   Motor                                                   Motor V8
#   Año                                                         2008
#   Kilometraje                                                610.0
#   Cero_km                                                    False
#   Accesorios     ['Techo panorámico', 'Llantas de aleación', 'C...
#   Valor                                                  116281.21
#   Name: HB20S, dtype: object),
#  ('Cielo Hatch',
#   Motor                                               Motor Diesel
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Panel digital', 'Central multimedia', 'Cámar...
#   Valor                                                   145197.7
#   Name: Cielo Hatch, dtype: object),
#  ('Livina',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Sensor crepuscular', 'Cámara de estacionamie...
#   Valor                                                    50742.1
#   Name: Livina, dtype: object),
#  ('Ducato',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         1999
#   Kilometraje                                              12887.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Panel digital', 'Sensor ...
#   Valor                                                   73033.53
#   Name: Ducato, dtype: object),
#  ('March',
#   Motor                                                   Motor V6
#   Año                                                         2007
#   Kilometraje                                              79607.0
#   Cero_km                                                    False
#   Accesorios     ['Asientos de cuero', 'Piloto automático', 'Se...
#   Valor                                                   54332.87
#   Name: March, dtype: object),
#  ('Cadillac XTS sedan',
#   Motor                                            Motor Diesel V6
#   Año                                                         1993
#   Kilometraje                                              90924.0
#   Cero_km                                                    False
#   Accesorios     ['Aire condicionado', 'Transmisión automática'...
#   Valor                                                   52207.45
#   Name: Cadillac XTS sedan, dtype: object),
#  ('Lamborghini Centenario',
#   Motor                                                   Motor V6
#   Año                                                         1995
#   Kilometraje                                              42733.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', 'Ventanas eléctricas', ...
#   Valor                                                    63578.5
#   Name: Lamborghini Centenario, dtype: object),
#  ('Hilux',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['4 X 4', 'Piloto automático', 'Techo panorámi...
#   Valor                                                   64507.72
#   Name: Hilux, dtype: object),
#  ('Grand Siena',
#   Motor                                            Motor Diesel V8
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Asientos de cuero', 'Panel digital', 'Sensor...
#   Valor                                                  115075.59
#   Name: Grand Siena, dtype: object),
#  ('Symbol',
#   Motor                                               Motor Diesel
#   Año                                                         2016
#   Kilometraje                                             117714.0
#   Cero_km                                                    False
#   Accesorios     ['4 X 4', 'Piloto automático', 'Sensor crepusc...
#   Valor                                                   133030.6
#   Name: Symbol, dtype: object),
#  ('Aston Martin V12 GT Zagato',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2011
#   Kilometraje                                             113885.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', 'Piloto automático', 'S...
#   Valor                                                  141591.86
#   Name: Aston Martin V12 GT Zagato, dtype: object),
#  ('Fusion',
#   Motor                                              Motor 1.8 16v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Control de tracción', 'Transmisión automátic...
#   Valor                                                  100380.28
#   Name: Fusion, dtype: object),
#  ('A4 Sedan',
#   Motor                                               Motor Diesel
#   Año                                                         2002
#   Kilometraje                                              30511.0
#   Cero_km                                                    False
#   Accesorios     ['Cámara de estacionamiento', '4 X 4', 'Cerrad...
#   Valor                                                   96369.04
#   Name: A4 Sedan, dtype: object),
#  ('Xsara Picasso',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2013
#   Kilometraje                                              74867.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Techo panorámico', 'Cent...
#   Valor                                                  142603.84
#   Name: Xsara Picasso, dtype: object),
#  ('207 SW',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2017
#   Kilometraje                                             119760.0
#   Cero_km                                                    False
#   Accesorios     ['Control de estabilidad', 'Cerraduras electri...
#   Valor                                                  117709.67
#   Name: 207 SW, dtype: object),
#  ('Star',
#   Motor                                                   Motor V6
#   Año                                                         2016
#   Kilometraje                                               8356.0
#   Cero_km                                                    False
#   Accesorios     ['Cámara de estacionamiento', '4 X 4', 'Centra...
#   Valor                                                  102241.54
#   Name: Star, dtype: object),
#  ('Doblò Cargo',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2008
#   Kilometraje                                              64247.0
#   Cero_km                                                    False
#   Accesorios     ['Frenos ABS', 'Techo panorámico', 'Ventanas e...
#   Valor                                                   96065.38
#   Name: Doblò Cargo, dtype: object),
#  ('Cadillac CTS',
#   Motor                                              Motor 1.8 16v
#   Año                                                         2018
#   Kilometraje                                              88661.0
#   Cero_km                                                    False
#   Accesorios     ['Cerraduras electricas', 'Sensor de lluvia', ...
#   Valor                                                   53894.61
#   Name: Cadillac CTS, dtype: object),
#  ('Cayenne',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2003
#   Kilometraje                                               4539.0
#   Cero_km                                                    False
#   Accesorios     ['Control de tracción', 'Piloto automático', '...
#   Valor                                                  123911.78
#   Name: Cayenne, dtype: object),
#  ('Fox',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2003
#   Kilometraje                                             110116.0
#   Cero_km                                                    False
#   Accesorios     ['Piloto automático', 'Transmisión automática'...
#   Valor                                                  101996.35
#   Name: Fox, dtype: object),
#  ('Tiida Hatch',
#   Motor                                            Motor Diesel V6
#   Año                                                         2004
#   Kilometraje                                              33215.0
#   Cero_km                                                    False
#   Accesorios     ['Techo panorámico', 'Cerraduras electricas', ...
#   Valor                                                   83431.66
#   Name: Tiida Hatch, dtype: object),
#  ('Dodge Charger',
#   Motor                                            Motor 2.4 Turbo
#   Año                                                         2010
#   Kilometraje                                              92001.0
#   Cero_km                                                    False
#   Accesorios     ['Ventanas eléctricas', 'Sensor crepuscular', ...
#   Valor                                                  122975.63
#   Name: Dodge Charger, dtype: object),
#  ('Face',
#   Motor                                                   Motor V8
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Control de estabilidad', 'Ventanas eléctrica...
#   Valor                                                   93227.73
#   Name: Face, dtype: object),
#  ('Prius',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2006
#   Kilometraje                                              81708.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Asientos de cuero', '...
#   Valor                                                   58762.65
#   Name: Prius, dtype: object),
#  ('Idea',
#   Motor                                                   Motor V6
#   Año                                                         2001
#   Kilometraje                                              70641.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', 'Piloto automático', 'C...
#   Valor                                                  139549.67
#   Name: Idea, dtype: object),
#  ('A8',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Panel digital', 'Techo panorámico', 'Piloto ...
#   Valor                                                  122016.42
#   Name: A8, dtype: object),
#  ('Série 1 Cabrio',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2015
#   Kilometraje                                              91277.0
#   Cero_km                                                    False
#   Accesorios     ['Ventanas eléctricas', 'Cerraduras electricas...
#   Valor                                                   72731.98
#   Name: Série 1 Cabrio, dtype: object),
#  ('Edge',
#   Motor                                                   Motor V6
#   Año                                                         2018
#   Kilometraje                                              26544.0
#   Cero_km                                                    False
#   Accesorios     ['Frenos ABS', 'Control de tracción', 'Sensor ...
#   Valor                                                   88416.54
#   Name: Edge, dtype: object),
#  ('Cadillac ATS sedan',
#   Motor                                              Motor 1.8 16v
#   Año                                                         2017
#   Kilometraje                                              52596.0
#   Cero_km                                                    False
#   Accesorios     ['Panel digital', 'Ventanas eléctricas', 'Tech...
#   Valor                                                   73873.42
# ...
#   Motor                                              Motor 1.8 16v
#   Año                                                         2011
#   Kilometraje                                              15987.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor crepuscular', 'Cerraduras electricas'...
#   Valor                                                   98156.35
#   Name: Phantom I Jonckheere Aerodynamic Coupe, dtype: object),
#  ('Boxer',
#   Motor                                                   Motor V6
#   Año                                                         2005
#   Kilometraje                                              53369.0
#   Cero_km                                                    False
#   Accesorios     ['Cerraduras electricas', 'Piloto automático',...
#   Valor                                                   112146.8
#   Name: Boxer, dtype: object),
#  ('Chana Cargo',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2007
#   Kilometraje                                              10077.0
#   Cero_km                                                    False
#   Accesorios     ['Techo panorámico', '4 X 4', 'Central multime...
#   Valor                                                  102729.63
#   Name: Chana Cargo, dtype: object),
#  ('Dodge Dakota',
#   Motor                                               Motor Diesel
#   Año                                                         1993
#   Kilometraje                                              71544.0
#   Cero_km                                                    False
#   Accesorios     ['Control de tracción', 'Sensor de estacionami...
#   Valor                                                  141083.35
#   Name: Dodge Dakota, dtype: object),
#  ('X1',
#   Motor                                            Motor Diesel V8
#   Año                                                         1991
#   Kilometraje                                                107.0
#   Cero_km                                                    False
#   Accesorios     ['4 X 4', 'Techo panorámico', 'Aire condiciona...
#   Valor                                                  102968.76
#   Name: X1, dtype: object),
#  ('GLA',
#   Motor                                               Motor 1.0 8v
#   Año                                                         1991
#   Kilometraje                                               8394.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Cámara de estacionamient...
#   Valor                                                   76310.01
#   Name: GLA, dtype: object),
#  ('Range Rover Sport',
#   Motor                                               Motor 1.0 8v
#   Año                                                         1997
#   Kilometraje                                              41498.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de estacionamiento', 'Cámara de estac...
#   Valor                                                  120481.74
#   Name: Range Rover Sport, dtype: object),
#  ('DS3',
#   Motor                                              Motor 1.8 16v
#   Año                                                         2000
#   Kilometraje                                             116002.0
#   Cero_km                                                    False
#   Accesorios     ['Control de estabilidad', 'Aire condicionado'...
#   Valor                                                   54559.18
#   Name: DS3, dtype: object),
#  ('Veracruz',
#   Motor                                            Motor Diesel V8
#   Año                                                         2007
#   Kilometraje                                             100858.0
#   Cero_km                                                    False
#   Accesorios     ['Control de estabilidad', 'Cámara de estacion...
#   Valor                                                   92957.64
#   Name: Veracruz, dtype: object),
#  ('Cadillac CTS coupe, sedan, and wagon',
#   Motor                                                   Motor V8
#   Año                                                         2006
#   Kilometraje                                              67475.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Sensor de estacionamient...
#   Valor                                                  127810.06
#   Name: Cadillac CTS coupe, sedan, and wagon, dtype: object),
#  ('i30 CW',
#   Motor                                               Motor Diesel
#   Año                                                         2015
#   Kilometraje                                               8497.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Ventanas eléctricas', 'C...
#   Valor                                                   73311.75
#   Name: i30 CW, dtype: object),
#  ('Phantom III',
#   Motor                                            Motor Diesel V6
#   Año                                                         2008
#   Kilometraje                                               4420.0
#   Cero_km                                                    False
#   Accesorios     ['Ventanas eléctricas', 'Asientos de cuero', '...
#   Valor                                                   65138.03
#   Name: Phantom III, dtype: object),
#  ('A3 Sedan',
#   Motor                                                   Motor V6
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Aire condicionado', 'Sensor de lluvia', 'Cer...
#   Valor                                                   90141.47
#   Name: A3 Sedan, dtype: object),
#  ('Aston Martin DB9 Volante',
#   Motor                                              Motor 2.0 16v
#   Año                                                         1996
#   Kilometraje                                              58537.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', 'Asientos de cuero', 'C...
#   Valor                                                   71160.36
#   Name: Aston Martin DB9 Volante, dtype: object),
#  ('Série 7 Sedã',
#   Motor                                               Motor Diesel
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Ventanas eléctricas', 'Cerraduras electricas...
#   Valor                                                   67539.79
#   Name: Série 7 Sedã, dtype: object),
#  ('Lamborghini Reventón',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Control de tracción', 'Aire condicionado', '...
#   Valor                                                   67664.86
#   Name: Lamborghini Reventón, dtype: object),
#  ('Grand Livina',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2014
#   Kilometraje                                             112016.0
#   Cero_km                                                    False
#   Accesorios     ['Control de tracción', 'Techo panorámico', 'V...
#   Valor                                                   68652.16
#   Name: Grand Livina, dtype: object),
#  ('V60',
#   Motor                                               Motor Diesel
#   Año                                                         2004
#   Kilometraje                                              91840.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Sensor crepuscular', ...
#   Valor                                                  114728.74
#   Name: V60, dtype: object),
#  ('Effa Hafei Picape Cabine Dupla',
#   Motor                                                   Motor V6
#   Año                                                         2008
#   Kilometraje                                             112787.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor crepuscular', 'Control de tracción', ...
#   Valor                                                  141645.08
#   Name: Effa Hafei Picape Cabine Dupla, dtype: object),
#  ('Benni Mini',
#   Motor                                                   Motor V8
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Sensor crepuscular', 'Transmisión automática...
#   Valor                                                  126247.84
#   Name: Benni Mini, dtype: object),
#  ('Uno',
#   Motor                                            Motor Diesel V6
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Central multimedia', 'Sensor crepuscular', '...
#   Valor                                                  128852.21
#   Name: Uno, dtype: object),
#  ('L200 Savana',
#   Motor                                              Motor 2.0 16v
#   Año                                                         2012
#   Kilometraje                                               9293.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Ventanas eléctricas', 'P...
#   Valor                                                  132384.76
#   Name: L200 Savana, dtype: object),
#  ('Santa Fe',
#   Motor                                              Motor 3.0 32v
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Cerraduras electricas', 'Aire condicionado',...
#   Valor                                                  129415.33
#   Name: Santa Fe, dtype: object),
#  ('RS5',
#   Motor                                                   Motor V6
#   Año                                                         1996
#   Kilometraje                                              55083.0
#   Cero_km                                                    False
#   Accesorios     ['Panel digital', 'Transmisión automática', 'V...
#   Valor                                                   89536.82
#   Name: RS5, dtype: object),
#  ('Cerato',
#   Motor                                                   Motor V6
#   Año                                                         2011
#   Kilometraje                                              48796.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de estacionamiento', 'Cámara de estac...
#   Valor                                                    87975.3
#   Name: Cerato, dtype: object),
#  ('XC60',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2019
#   Kilometraje                                                  NaN
#   Cero_km                                                     True
#   Accesorios     ['Panel digital', 'Piloto automático', 'Centra...
#   Valor                                                   77675.79
#   Name: XC60, dtype: object),
#  ('LS 460L',
#   Motor                                            Motor Diesel V8
#   Año                                                         2010
#   Kilometraje                                              89685.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Frenos ABS', 'Control...
#   Valor                                                   58881.67
#   Name: LS 460L, dtype: object),
#  ('Lamborghini Sesto Elemento',
#   Motor                                                   Motor V8
#   Año                                                         2007
#   Kilometraje                                              85384.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor crepuscular', 'Frenos ABS', 'Aire con...
#   Valor                                                   55081.99
#   Name: Lamborghini Sesto Elemento, dtype: object),
#  ('Lamborghini Huracán',
#   Motor                                                   Motor V8
#   Año                                                         1994
#   Kilometraje                                              98108.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Sensor de estacionamient...
#   Valor                                                  118826.44
#   Name: Lamborghini Huracán, dtype: object),
#  ('A7',
#   Motor                                               Motor 1.0 8v
#   Año                                                         2007
#   Kilometraje                                              71280.0
#   Cero_km                                                    False
#   Accesorios     ['Sensor de lluvia', 'Ventanas eléctricas', 'S...
#   Valor                                                  137627.62
#   Name: A7, dtype: object),
#  ('Phantom 2013',
#   Motor                                                   Motor V8
#   Año                                                         2014
#   Kilometraje                                              27505.0
#   Cero_km                                                    False
#   Accesorios     ['Control de estabilidad', 'Piloto automático'...
#   Valor                                                   51759.58
#   Name: Phantom 2013, dtype: object),
#  ('Cadillac Ciel concept',
#   Motor                                                   Motor V8
#   Año                                                         1991
#   Kilometraje                                              29981.0
#   Cero_km                                                    False
#   Accesorios     ['Asientos de cuero', 'Panel digital', 'Sensor...
#   Valor                                                   51667.06
#   Name: Cadillac Ciel concept, dtype: object),
#  ('Classe GLK',
#   Motor                                      Motor 5.0 V8 Bi-Turbo
#   Año                                                         2002
#   Kilometraje                                              52637.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Control de tracción',...
#   Valor                                                   68934.03
#   Name: Classe GLK, dtype: object),
#  ('Aston Martin DB5',
#   Motor                                               Motor Diesel
#   Año                                                         1996
#   Kilometraje                                               7685.0
#   Cero_km                                                    False
#   Accesorios     ['Aire condicionado', '4 X 4', 'Transmisión au...
#   Valor                                                   122110.9
#   Name: Aston Martin DB5, dtype: object),
#  ('Macan',
#   Motor                                            Motor Diesel V6
#   Año                                                         1992
#   Kilometraje                                              50188.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', 'Techo panorámico', 'Ve...
#   Valor                                                   90381.47
#   Name: Macan, dtype: object)]

# %%
for index, row in dataset.iterrows():
  if(2019 - row.Año != 0):
    dataset.loc[index, 'km_media'] = row.Kilometraje / (2019 - row.Año)
  else:
    dataset.loc[index, 'km_media'] = 0

dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# Nombre
# Jetta Variant          ['Llantas de aleación', 'Cerraduras electricas...
# Passat                 ['Central multimedia', 'Techo panorámico', 'Fr...
# Crossfox               ['Piloto automático', 'Control de estabilidad'...
# DS5                    ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# Aston Martin DB4       ['Llantas de aleación', '4 X 4', 'Central mult...
# ...                                                                  ...
# Phantom 2013           ['Control de estabilidad', 'Piloto automático'...
# Cadillac Ciel concept  ['Asientos de cuero', 'Panel digital', 'Sensor...
# Classe GLK             ['Llantas de aleación', 'Control de tracción',...
# Aston Martin DB5       ['Aire condicionado', '4 X 4', 'Transmisión au...
# Macan                  ['Central multimedia', 'Techo panorámico', 'Ve...
#
#                            Valor     km_media
# Nombre
# Jetta Variant           88078.64  2775.625000
# Passat                 106161.94   204.000000
# Crossfox                72832.16  1280.103448
# DS5                    124549.07     0.000000
# Aston Martin DB4        92612.10  1981.307692
# ...                          ...          ...
# Phantom 2013            51759.58  5501.000000
# Cadillac Ciel concept   51667.06  1070.750000
# Classe GLK              68934.03  3096.294118
# Aston Martin DB5       122110.90   334.130435
# Macan                   90381.47  1858.814815
#
# [258 rows x 7 columns]

# %%
list(dataset.itertuples())
# Out:
# [Pandas(Index='Jetta Variant', Motor='Motor 4.0 Turbo', Año=2003, Kilometraje=44410.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Cerraduras electricas', 'Piloto automático', 'Asientos de cuero', 'Aire condicionado', 'Sensor de estacionamiento', 'Sensor crepuscular', 'Sensor de lluvia']", Valor=88078.64, km_media=2775.625),
#  Pandas(Index='Passat', Motor='Motor Diesel', Año=1991, Kilometraje=5712.0, Cero_km=False, Accesorios="['Central multimedia', 'Techo panorámico', 'Frenos ABS', '4 X 4', 'Panel digital', 'Piloto automático', 'Asientos de cuero', 'Cámara de estacionamiento']", Valor=106161.94, km_media=204.0),
#  Pandas(Index='Crossfox', Motor='Motor Diesel V8', Año=1990, Kilometraje=37123.0, Cero_km=False, Accesorios="['Piloto automático', 'Control de estabilidad', 'Sensor crepuscular', 'Frenos ABS', 'Transmisión automática', 'Asientos de cuero', 'Central multimedia', 'Ventanas eléctricas']", Valor=72832.16, km_media=1280.103448275862),
#  Pandas(Index='DS5', Motor='Motor 2.4 Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Cerraduras electricas', '4 X 4', 'Ventanas eléctricas', 'Sensor crepuscular', 'Sensor de lluvia', 'Cámara de estacionamiento', 'Aire condicionado', 'Llantas de aleación']", Valor=124549.07, km_media=0.0),
#  Pandas(Index='Aston Martin DB4', Motor='Motor 2.4 Turbo', Año=2006, Kilometraje=25757.0, Cero_km=False, Accesorios="['Llantas de aleación', '4 X 4', 'Central multimedia', 'Aire condicionado', 'Control de estabilidad', 'Transmisión automática', 'Sensor de estacionamiento', 'Piloto automático']", Valor=92612.1, km_media=1981.3076923076924),
#  Pandas(Index='Palio Weekend', Motor='Motor 1.8 16v', Año=2012, Kilometraje=10728.0, Cero_km=False, Accesorios="['Sensor de estacionamiento', 'Techo panorámico', 'Sensor crepuscular', 'Panel digital', 'Aire condicionado', 'Llantas de aleación', 'Control de estabilidad', 'Asientos de cuero']", Valor=97497.73, km_media=1532.5714285714287),
#  Pandas(Index='A5', Motor='Motor 4.0 Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Transmisión automática', 'Cámara de estacionamiento', 'Frenos ABS', 'Control de tracción', 'Central multimedia', 'Cerraduras electricas', 'Sensor crepuscular', 'Llantas de aleación']", Valor=56445.2, km_media=0.0),
#  Pandas(Index='Série 3 Cabrio', Motor='Motor 1.0 8v', Año=2009, Kilometraje=77599.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Sensor crepuscular', 'Control de tracción', 'Techo panorámico', 'Cerraduras electricas', 'Piloto automático', 'Panel digital', 'Cámara de estacionamiento']", Valor=112310.44, km_media=7759.9),
#  Pandas(Index='Dodge Jorney', Motor='Motor 3.0 32v', Año=2010, Kilometraje=99197.0, Cero_km=False, Accesorios="['Ventanas eléctricas', 'Piloto automático', 'Techo panorámico', 'Aire condicionado', 'Asientos de cuero', 'Transmisión automática', 'Llantas de aleación', 'Cerraduras electricas']", Valor=120716.27, km_media=11021.888888888889),
#  Pandas(Index='Carens', Motor='Motor 5.0 V8 Bi-Turbo', Año=2011, Kilometraje=37978.0, Cero_km=False, Accesorios="['Aire condicionado', 'Panel digital', 'Central multimedia', 'Sensor crepuscular', 'Transmisión automática', 'Llantas de aleación', 'Control de tracción', 'Cámara de estacionamiento']", Valor=76566.49, km_media=4747.25),
#  Pandas(Index='Ford Edge', Motor='Motor Diesel V6', Año=2002, Kilometraje=12859.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Llantas de aleación', 'Techo panorámico', 'Sensor de lluvia', 'Cerraduras electricas', 'Sensor de estacionamiento', 'Control de tracción', 'Aire condicionado']", Valor=71647.59, km_media=756.4117647058823),
#  Pandas(Index='Courier', Motor='Motor Diesel V8', Año=2007, Kilometraje=8052.0, Cero_km=False, Accesorios="['Central multimedia', '4 X 4', 'Piloto automático', 'Techo panorámico', 'Control de estabilidad', 'Cámara de estacionamiento', 'Asientos de cuero', 'Ventanas eléctricas']", Valor=73919.53, km_media=671.0),
#  Pandas(Index='S-18', Motor='Motor V6', Año=2001, Kilometraje=89773.0, Cero_km=False, Accesorios="['Asientos de cuero', 'Sensor de lluvia', 'Llantas de aleación', 'Central multimedia', 'Cerraduras electricas', 'Aire condicionado', 'Cámara de estacionamiento', 'Sensor crepuscular']", Valor=112732.99, km_media=4987.388888888889),
#  Pandas(Index='J5', Motor='Motor V6', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Sensor crepuscular', 'Panel digital', 'Llantas de aleación', 'Frenos ABS', 'Transmisión automática', 'Control de tracción', 'Central multimedia', 'Cámara de estacionamiento']", Valor=53183.38, km_media=0.0),
#  Pandas(Index='F-Type Coupé', Motor='Motor 5.0 V8 Bi-Turbo', Año=2009, Kilometraje=41457.0, Cero_km=False, Accesorios="['Piloto automático', 'Sensor crepuscular', 'Sensor de lluvia', 'Aire condicionado', 'Sensor de estacionamiento', 'Control de tracción', 'Cámara de estacionamiento', 'Ventanas eléctricas']", Valor=127488.42, km_media=4145.7),
#  Pandas(Index='RAM', Motor='Motor Diesel V8', Año=2016, Kilometraje=115607.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Transmisión automática', 'Sensor de lluvia', 'Central multimedia', 'Control de estabilidad', '4 X 4', 'Frenos ABS', 'Piloto automático']", Valor=59910.4, km_media=38535.666666666664),
#  Pandas(Index='Série 1', Motor='Motor 3.0 32v', Año=2012, Kilometraje=46449.0, Cero_km=False, Accesorios="['Techo panorámico', 'Cámara de estacionamiento', 'Cerraduras electricas', '4 X 4', 'Panel digital', 'Central multimedia', 'Llantas de aleación', 'Frenos ABS']", Valor=61118.59, km_media=6635.571428571428),
#  Pandas(Index='A3', Motor='Motor 1.0 8v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['4 X 4', 'Piloto automático', 'Central multimedia', 'Techo panorámico', 'Sensor de estacionamiento', 'Control de tracción', 'Control de estabilidad', 'Sensor de lluvia']", Valor=88552.39, km_media=0.0),
#  Pandas(Index='XC90', Motor='Motor 1.0 8v', Año=2016, Kilometraje=37086.0, Cero_km=False, Accesorios="['Cerraduras electricas', 'Ventanas eléctricas', 'Techo panorámico', 'Central multimedia', 'Control de estabilidad', '4 X 4', 'Transmisión automática', 'Sensor de lluvia']", Valor=62696.69, km_media=12362.0),
#  Pandas(Index='RS 3 Sportback', Motor='Motor 3.0 32v', Año=2017, Kilometraje=15173.0, Cero_km=False, Accesorios="['4 X 4', 'Piloto automático', 'Central multimedia', 'Asientos de cuero', 'Sensor de lluvia', 'Llantas de aleación', 'Aire condicionado', 'Sensor crepuscular']", Valor=101726.3, km_media=7586.5),
#  Pandas(Index='Pajero Sport', Motor='Motor 1.0 8v', Año=2002, Kilometraje=101193.0, Cero_km=False, Accesorios="['Sensor de estacionamiento', 'Piloto automático', 'Transmisión automática', 'Panel digital', 'Frenos ABS', 'Cámara de estacionamiento', 'Llantas de aleación', 'Control de estabilidad']", Valor=106147.38, km_media=5952.529411764706),
#  Pandas(Index='Série 1 M', Motor='Motor V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Control de estabilidad', 'Central multimedia', 'Panel digital', 'Sensor crepuscular', 'Sensor de lluvia', 'Cámara de estacionamiento', 'Aire condicionado', 'Frenos ABS']", Valor=94564.4, km_media=0.0),
#  Pandas(Index='Lamborghini Obvious', Motor='Motor Diesel V6', Año=1994, Kilometraje=98079.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Transmisión automática', 'Cerraduras electricas', 'Techo panorámico', 'Control de estabilidad', 'Central multimedia', 'Sensor de estacionamiento', 'Sensor crepuscular']", Valor=133529.84, km_media=3923.16),
#  Pandas(Index='Effa Hafei Picape Baú', Motor='Motor Diesel', Año=1991, Kilometraje=102959.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Panel digital', 'Ventanas eléctricas', '4 X 4', 'Sensor crepuscular', 'Aire condicionado', 'Cerraduras electricas', 'Central multimedia']", Valor=125684.65, km_media=3677.1071428571427),
#  Pandas(Index='Lamborghini Murciélago', Motor='Motor 5.0 V8 Bi-Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Frenos ABS', 'Transmisión automática', 'Aire condicionado', 'Cámara de estacionamiento', 'Control de tracción', 'Central multimedia', 'Sensor crepuscular', 'Control de estabilidad']", Valor=121596.21, km_media=0.0),
#  Pandas(Index='Up!', Motor='Motor Diesel V6', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Sensor de estacionamiento', 'Ventanas eléctricas', 'Frenos ABS', 'Central multimedia', 'Control de estabilidad', 'Sensor de lluvia', 'Transmisión automática', 'Piloto automático']", Valor=71367.1, km_media=0.0),
#  Pandas(Index='Fiesta Rocam Sedan', Motor='Motor 4.0 Turbo', Año=2016, Kilometraje=5795.0, Cero_km=False, Accesorios="['Aire condicionado', 'Asientos de cuero', 'Transmisión automática', 'Cámara de estacionamiento', 'Piloto automático', 'Control de estabilidad', 'Sensor de lluvia', 'Ventanas eléctricas']", Valor=95347.75, km_media=1931.6666666666667),
#  Pandas(Index='Sandero Stepway', Motor='Motor 3.0 32v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Frenos ABS', 'Aire condicionado', 'Techo panorámico', 'Panel digital', 'Sensor de estacionamiento', 'Ventanas eléctricas', 'Sensor crepuscular', 'Piloto automático']", Valor=105432.84, km_media=0.0),
#  Pandas(Index='Cayman S', Motor='Motor 3.0 32v', Año=2002, Kilometraje=58848.0, Cero_km=False, Accesorios="['Transmisión automática', 'Sensor de estacionamiento', 'Llantas de aleación', 'Ventanas eléctricas', '4 X 4', 'Asientos de cuero', 'Panel digital', 'Cerraduras electricas']", Valor=57045.27, km_media=3461.6470588235293),
#  Pandas(Index='V40', Motor='Motor 4.0 Turbo', Año=1991, Kilometraje=94381.0, Cero_km=False, Accesorios="['Cámara de estacionamiento', 'Sensor de estacionamiento', 'Llantas de aleación', 'Control de tracción', 'Frenos ABS', 'Transmisión automática', 'Asientos de cuero', 'Sensor de lluvia']", Valor=120432.7, km_media=3370.75),
#  Pandas(Index='Classe SLS AMG', Motor='Motor 1.0 8v', Año=1997, Kilometraje=30163.0, Cero_km=False, Accesorios="['Sensor de estacionamiento', 'Control de estabilidad', 'Sensor de lluvia', 'Cerraduras electricas', 'Panel digital', 'Sensor crepuscular', 'Piloto automático', 'Asientos de cuero']", Valor=70707.2, km_media=1371.0454545454545),
#  Pandas(Index='Gol G4', Motor='Motor 2.0 16v', Año=1995, Kilometraje=53332.0, Cero_km=False, Accesorios="['Sensor crepuscular', '4 X 4', 'Ventanas eléctricas', 'Control de tracción', 'Aire condicionado', 'Cámara de estacionamiento', 'Panel digital', 'Frenos ABS']", Valor=69105.18, km_media=2222.1666666666665),
#  Pandas(Index='Linea', Motor='Motor 1.0 8v', Año=2018, Kilometraje=17720.0, Cero_km=False, Accesorios="['Piloto automático', 'Panel digital', 'Ventanas eléctricas', 'Control de tracción', 'Techo panorámico', 'Aire condicionado', 'Cámara de estacionamiento', 'Llantas de aleación']", Valor=59358.69, km_media=17720.0),
#  Pandas(Index='Ford F100', Motor='Motor 2.0 16v', Año=1991, Kilometraje=33808.0, Cero_km=False, Accesorios="['Control de tracción', 'Sensor crepuscular', 'Cerraduras electricas', 'Asientos de cuero', 'Cámara de estacionamiento', 'Llantas de aleación', 'Central multimedia', '4 X 4']", Valor=65955.4, km_media=1207.4285714285713),
#  Pandas(Index='J2', Motor='Motor V8', Año=2014, Kilometraje=90684.0, Cero_km=False, Accesorios="['Techo panorámico', 'Sensor de estacionamiento', 'Asientos de cuero', 'Ventanas eléctricas', 'Frenos ABS', 'Llantas de aleación', 'Cerraduras electricas', 'Transmisión automática']", Valor=60017.03, km_media=18136.8),
#  Pandas(Index='Aston Martin DBS', Motor='Motor V8', Año=1995, Kilometraje=43975.0, Cero_km=False, Accesorios="['Techo panorámico', 'Piloto automático', 'Aire condicionado', 'Ventanas eléctricas', 'Asientos de cuero', 'Cerraduras electricas', 'Sensor de lluvia', 'Sensor crepuscular']", Valor=118909.52, km_media=1832.2916666666667),
#  Pandas(Index='Pajero TR4', Motor='Motor 2.4 Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Control de tracción', 'Asientos de cuero', 'Cámara de estacionamiento', 'Control de estabilidad', 'Ventanas eléctricas', 'Piloto automático', 'Llantas de aleación', 'Techo panorámico']", Valor=51606.59, km_media=0.0),
#  Pandas(Index='Polo Sedan', Motor='Motor V6', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Sensor de lluvia', 'Sensor crepuscular', 'Aire condicionado', 'Sensor de estacionamiento', 'Techo panorámico', 'Transmisión automática', 'Ventanas eléctricas', 'Cerraduras electricas']", Valor=123281.87, km_media=0.0),
#  Pandas(Index='California', Motor='Motor 1.0 8v', Año=2009, Kilometraje=5526.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Aire condicionado', 'Cámara de estacionamiento', 'Panel digital', 'Cerraduras electricas', 'Sensor crepuscular', 'Central multimedia', 'Frenos ABS']", Valor=69770.18, km_media=552.6),
#  Pandas(Index='S60', Motor='Motor 2.4 Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Techo panorámico', 'Frenos ABS', '4 X 4', 'Aire condicionado', 'Control de tracción', 'Central multimedia', 'Panel digital', 'Sensor crepuscular']", Valor=102609.54, km_media=0.0),
#  Pandas(Index='Tucson', Motor='Motor 2.0 16v', Año=2013, Kilometraje=93415.0, Cero_km=False, Accesorios="['Ventanas eléctricas', 'Sensor crepuscular', 'Frenos ABS', 'Cámara de estacionamiento', 'Piloto automático', 'Cerraduras electricas', 'Transmisión automática', '4 X 4']", Valor=67997.19, km_media=15569.166666666666),
#  Pandas(Index='HB20', Motor='Motor V6', Año=2003, Kilometraje=40762.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Cerraduras electricas', 'Control de tracción', 'Frenos ABS', 'Aire condicionado', 'Techo panorámico', 'Ventanas eléctricas', 'Transmisión automática']", Valor=135235.29, km_media=2547.625),
#  Pandas(Index='Optima', Motor='Motor 1.8 16v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Central multimedia', 'Aire condicionado', 'Techo panorámico', 'Frenos ABS', 'Panel digital', 'Control de estabilidad', '4 X 4', 'Sensor de estacionamiento']", Valor=86641.34, km_media=0.0),
#  Pandas(Index='Logan', Motor='Motor 4.0 Turbo', Año=2002, Kilometraje=86302.0, Cero_km=False, Accesorios="['Cámara de estacionamiento', 'Ventanas eléctricas', 'Central multimedia', 'Sensor de lluvia', 'Sensor crepuscular', 'Panel digital', 'Aire condicionado', 'Asientos de cuero']", Valor=136818.39, km_media=5076.588235294118),
#  Pandas(Index='Range Rover Vogue', Motor='Motor 1.0 8v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['4 X 4', 'Ventanas eléctricas', 'Llantas de aleación', 'Central multimedia', 'Cámara de estacionamiento', 'Sensor de estacionamiento', 'Piloto automático', 'Aire condicionado']", Valor=117626.73, km_media=0.0),
#  Pandas(Index='Sonata', Motor='Motor 5.0 V8 Bi-Turbo', Año=2002, Kilometraje=9755.0, Cero_km=False, Accesorios="['Piloto automático', 'Aire condicionado', 'Ventanas eléctricas', '4 X 4', 'Sensor de estacionamiento', 'Asientos de cuero', 'Cerraduras electricas', 'Control de estabilidad']", Valor=56208.7, km_media=573.8235294117648),
#  Pandas(Index='Ford New Fiesta Sedan', Motor='Motor 3.0 32v', Año=2004, Kilometraje=69945.0, Cero_km=False, Accesorios="['Techo panorámico', 'Panel digital', 'Aire condicionado', 'Central multimedia', '4 X 4', 'Control de estabilidad', 'Transmisión automática', 'Sensor de lluvia']", Valor=84222.65, km_media=4663.0),
#  Pandas(Index='Série 5 Gran Turismo', Motor='Motor 4.0 Turbo', Año=2001, Kilometraje=2395.0, Cero_km=False, Accesorios="['Control de tracción', 'Piloto automático', 'Aire condicionado', 'Asientos de cuero', 'Frenos ABS', 'Central multimedia', 'Sensor de lluvia', '4 X 4']", Valor=90781.65, km_media=133.05555555555554),
#  Pandas(Index='CR-V', Motor='Motor Diesel V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Transmisión automática', 'Central multimedia', 'Ventanas eléctricas', 'Control de estabilidad', 'Control de tracción', 'Asientos de cuero', 'Frenos ABS', 'Panel digital']", Valor=64701.1, km_media=0.0),
#  Pandas(Index='Ford EcoSport', Motor='Motor 1.0 8v', Año=2003, Kilometraje=80349.0, Cero_km=False, Accesorios="['Ventanas eléctricas', 'Piloto automático', 'Panel digital', 'Frenos ABS', 'Asientos de cuero', 'Techo panorámico', 'Sensor de lluvia', 'Llantas de aleación']", Valor=126350.49, km_media=5021.8125),
#  Pandas(Index='Versa', Motor='Motor 3.0 32v', Año=2009, Kilometraje=85554.0, Cero_km=False, Accesorios="['Asientos de cuero', 'Aire condicionado', 'Llantas de aleación', 'Sensor crepuscular', 'Cerraduras electricas', 'Sensor de estacionamiento', 'Piloto automático', 'Control de estabilidad']", Valor=148152.89, km_media=8555.4),
#  Pandas(Index='Classe E', Motor='Motor 1.0 8v', Año=2006, Kilometraje=50496.0, Cero_km=False, Accesorios="['Frenos ABS', 'Sensor de estacionamiento', 'Central multimedia', 'Cámara de estacionamiento', 'Aire condicionado', 'Techo panorámico', 'Transmisión automática', 'Piloto automático']", Valor=132298.83, km_media=3884.3076923076924),
#  Pandas(Index='Carnival', Motor='Motor V8', Año=2000, Kilometraje=67716.0, Cero_km=False, Accesorios="['Cerraduras electricas', 'Transmisión automática', 'Cámara de estacionamiento', 'Frenos ABS', 'Central multimedia', 'Llantas de aleación', 'Techo panorámico', 'Control de estabilidad']", Valor=137627.63, km_media=3564.0),
#  Pandas(Index='Aston Martin V8 Vantage Roadster', Motor='Motor 2.4 Turbo', Año=2006, Kilometraje=93947.0, Cero_km=False, Accesorios="['Transmisión automática', 'Cámara de estacionamiento', 'Ventanas eléctricas', 'Control de estabilidad', 'Central multimedia', 'Piloto automático', 'Sensor crepuscular', 'Cerraduras electricas']", Valor=80422.71, km_media=7226.692307692308),
#  Pandas(Index='Hoggar', Motor='Motor 5.0 V8 Bi-Turbo', Año=2010, Kilometraje=35345.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Asientos de cuero', 'Sensor de lluvia', 'Panel digital', 'Ventanas eléctricas', 'Frenos ABS', 'Control de tracción', 'Aire condicionado']", Valor=56373.99, km_media=3927.222222222222),
#  Pandas(Index='A1', Motor='Motor 5.0 V8 Bi-Turbo', Año=1994, Kilometraje=81007.0, Cero_km=False, Accesorios="['Panel digital', 'Transmisión automática', 'Cámara de estacionamiento', 'Frenos ABS', 'Control de estabilidad', 'Sensor crepuscular', '4 X 4', 'Aire condicionado']", Valor=70846.03, km_media=3240.28),
#  Pandas(Index='Aston Martin DB7 Vantage', Motor='Motor V6', Año=2007, Kilometraje=119513.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Piloto automático', 'Techo panorámico', 'Frenos ABS', 'Transmisión automática', 'Central multimedia', 'Ventanas eléctricas', 'Sensor de estacionamiento']", Valor=128694.23, km_media=9959.416666666666),
#  Pandas(Index='CLA', Motor='Motor 1.0 8v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Central multimedia', 'Sensor de lluvia', 'Control de estabilidad', 'Sensor crepuscular', 'Llantas de aleación', 'Piloto automático', '4 X 4', 'Ventanas eléctricas']", Valor=133329.19, km_media=0.0),
#  Pandas(Index='Accord', Motor='Motor V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Sensor de estacionamiento', 'Aire condicionado', 'Central multimedia', 'Control de tracción', 'Llantas de aleación', 'Techo panorámico', 'Sensor de lluvia', 'Cámara de estacionamiento']", Valor=131961.43, km_media=0.0),
#  Pandas(Index='EXTRA 103EX', Motor='Motor 2.0 16v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Sensor de estacionamiento', 'Central multimedia', 'Asientos de cuero', 'Sensor crepuscular', 'Techo panorámico', 'Control de tracción', 'Piloto automático', 'Sensor de lluvia']", Valor=112033.27, km_media=0.0),
#  Pandas(Index='Sorento', Motor='Motor Diesel', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Sensor de lluvia', 'Cámara de estacionamiento', 'Sensor de estacionamiento', 'Control de estabilidad', 'Llantas de aleación', 'Cerraduras electricas', 'Ventanas eléctricas', 'Control de tracción']", Valor=81399.35, km_media=0.0),
#  Pandas(Index='Tiggo', Motor='Motor 3.0 32v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Cámara de estacionamiento', 'Frenos ABS', 'Piloto automático', 'Ventanas eléctricas', 'Transmisión automática', 'Sensor crepuscular', 'Sensor de estacionamiento', 'Control de tracción']", Valor=97163.1, km_media=0.0),
#  Pandas(Index='New Fiesta Hatch', Motor='Motor Diesel', Año=2017, Kilometraje=118895.0, Cero_km=False, Accesorios="['Sensor de estacionamiento', 'Cerraduras electricas', 'Piloto automático', 'Llantas de aleación', 'Control de tracción', 'Aire condicionado', '4 X 4', 'Sensor crepuscular']", Valor=66007.16, km_media=59447.5),
#  Pandas(Index='Jeep Renegade', Motor='Motor 5.0 V8 Bi-Turbo', Año=2011, Kilometraje=48509.0, Cero_km=False, Accesorios="['Ventanas eléctricas', 'Techo panorámico', 'Asientos de cuero', 'Cerraduras electricas', 'Sensor de lluvia', 'Control de tracción', 'Frenos ABS', 'Central multimedia']", Valor=128776.22, km_media=6063.625),
#  Pandas(Index='Lamborghini Ankonian', Motor='Motor 2.0 16v', Año=2001, Kilometraje=100912.0, Cero_km=False, Accesorios="['Asientos de cuero', 'Cámara de estacionamiento', 'Central multimedia', '4 X 4', 'Sensor de lluvia', 'Aire condicionado', 'Llantas de aleación', 'Sensor crepuscular']", Valor=142623.02, km_media=5606.222222222223),
#  Pandas(Index='Space Cross', Motor='Motor 5.0 V8 Bi-Turbo', Año=1996, Kilometraje=95649.0, Cero_km=False, Accesorios="['Techo panorámico', 'Ventanas eléctricas', 'Sensor de lluvia', 'Cerraduras electricas', 'Llantas de aleación', 'Sensor crepuscular', 'Frenos ABS', 'Aire condicionado']", Valor=136930.13, km_media=4158.652173913043),
#  Pandas(Index='Touareg', Motor='Motor V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Control de estabilidad', 'Piloto automático', 'Sensor crepuscular', 'Cerraduras electricas', 'Cámara de estacionamiento', 'Llantas de aleación', 'Panel digital', 'Techo panorámico']", Valor=66526.61, km_media=0.0),
#  Pandas(Index='Classe M', Motor='Motor 1.0 8v', Año=1994, Kilometraje=90495.0, Cero_km=False, Accesorios="['Central multimedia', 'Asientos de cuero', 'Llantas de aleación', '4 X 4', 'Ventanas eléctricas', 'Transmisión automática', 'Aire condicionado', 'Control de estabilidad']", Valor=114154.87, km_media=3619.8),
#  Pandas(Index='Lancer Evolution X', Motor='Motor Diesel V6', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Ventanas eléctricas', 'Transmisión automática', 'Control de tracción', 'Cerraduras electricas', 'Techo panorámico', 'Aire condicionado', 'Sensor crepuscular', 'Central multimedia']", Valor=142392.75, km_media=0.0),
#  Pandas(Index='Kangoo Express', Motor='Motor Diesel', Año=2007, Kilometraje=29132.0, Cero_km=False, Accesorios="['Asientos de cuero', 'Transmisión automática', 'Piloto automático', 'Control de estabilidad', 'Central multimedia', 'Sensor de lluvia', 'Techo panorámico', 'Panel digital']", Valor=146716.91, km_media=2427.6666666666665),
#  Pandas(Index='SW4', Motor='Motor Diesel V6', Año=1994, Kilometraje=23802.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Asientos de cuero', 'Control de tracción', 'Piloto automático', 'Central multimedia', 'Cámara de estacionamiento', 'Techo panorámico', 'Llantas de aleación']", Valor=122485.68, km_media=952.08),
#  Pandas(Index='Cadillac ELR', Motor='Motor 1.0 8v', Año=2007, Kilometraje=84992.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Cerraduras electricas', 'Techo panorámico', 'Ventanas eléctricas', 'Sensor de estacionamiento', 'Sensor de lluvia', 'Llantas de aleación', 'Frenos ABS']", Valor=97951.03, km_media=7082.666666666667),
#  Pandas(Index='Doblò', Motor='Motor 1.8 16v', Año=1997, Kilometraje=54395.0, Cero_km=False, Accesorios="['Cámara de estacionamiento', 'Techo panorámico', 'Control de estabilidad', 'Sensor de estacionamiento', 'Cerraduras electricas', 'Ventanas eléctricas', 'Asientos de cuero', 'Piloto automático']", Valor=78283.49, km_media=2472.5),
#  Pandas(Index='Lamborghini Egoista', Motor='Motor 3.0 32v', Año=2006, Kilometraje=26731.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Control de tracción', 'Central multimedia', 'Control de estabilidad', 'Sensor de estacionamiento', 'Panel digital', 'Cámara de estacionamiento', 'Sensor crepuscular']", Valor=83434.04, km_media=2056.230769230769),
#  Pandas(Index='Fit', Motor='Motor Diesel', Año=2013, Kilometraje=44329.0, Cero_km=False, Accesorios="['Frenos ABS', 'Cámara de estacionamiento', 'Transmisión automática', 'Techo panorámico', 'Piloto automático', 'Ventanas eléctricas', 'Sensor de lluvia', 'Sensor crepuscular']", Valor=77836.23, km_media=7388.166666666667),
#  Pandas(Index='C5', Motor='Motor 2.0 16v', Año=1994, Kilometraje=118236.0, Cero_km=False, Accesorios="['Panel digital', 'Techo panorámico', 'Piloto automático', 'Control de estabilidad', 'Sensor crepuscular', 'Sensor de estacionamiento', 'Cerraduras electricas', 'Sensor de lluvia']", Valor=60813.92, km_media=4729.44),
#  Pandas(Index='Celer Hatch', Motor='Motor V8', Año=2008, Kilometraje=113808.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Transmisión automática', 'Frenos ABS', 'Llantas de aleación', 'Sensor crepuscular', 'Sensor de lluvia', 'Central multimedia', 'Aire condicionado']", Valor=91353.86, km_media=10346.181818181818),
#  Pandas(Index='HB20S', Motor='Motor V8', Año=2008, Kilometraje=610.0, Cero_km=False, Accesorios="['Techo panorámico', 'Llantas de aleación', 'Cerraduras electricas', 'Control de tracción', 'Frenos ABS', 'Piloto automático', 'Sensor crepuscular', 'Sensor de estacionamiento']", Valor=116281.21, km_media=55.45454545454545),
#  Pandas(Index='Cielo Hatch', Motor='Motor Diesel', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Panel digital', 'Central multimedia', 'Cámara de estacionamiento', 'Cerraduras electricas', 'Control de tracción', 'Sensor de estacionamiento', 'Techo panorámico', 'Aire condicionado']", Valor=145197.7, km_media=0.0),
#  Pandas(Index='Livina', Motor='Motor 2.0 16v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Sensor crepuscular', 'Cámara de estacionamiento', 'Central multimedia', 'Llantas de aleación', 'Panel digital', 'Transmisión automática', 'Asientos de cuero', 'Sensor de estacionamiento']", Valor=50742.1, km_media=0.0),
#  Pandas(Index='Ducato', Motor='Motor 5.0 V8 Bi-Turbo', Año=1999, Kilometraje=12887.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Panel digital', 'Sensor crepuscular', '4 X 4', 'Sensor de estacionamiento', 'Asientos de cuero', 'Cerraduras electricas', 'Transmisión automática']", Valor=73033.53, km_media=644.35),
#  Pandas(Index='March', Motor='Motor V6', Año=2007, Kilometraje=79607.0, Cero_km=False, Accesorios="['Asientos de cuero', 'Piloto automático', 'Sensor de estacionamiento', 'Ventanas eléctricas', 'Control de estabilidad', 'Frenos ABS', '4 X 4', 'Transmisión automática']", Valor=54332.87, km_media=6633.916666666667),
#  Pandas(Index='Cadillac XTS sedan', Motor='Motor Diesel V6', Año=1993, Kilometraje=90924.0, Cero_km=False, Accesorios="['Aire condicionado', 'Transmisión automática', 'Sensor de estacionamiento', 'Cerraduras electricas', 'Cámara de estacionamiento', 'Control de tracción', 'Asientos de cuero', 'Panel digital']", Valor=52207.45, km_media=3497.076923076923),
#  Pandas(Index='Lamborghini Centenario', Motor='Motor V6', Año=1995, Kilometraje=42733.0, Cero_km=False, Accesorios="['Central multimedia', 'Ventanas eléctricas', 'Sensor de estacionamiento', '4 X 4', 'Cámara de estacionamiento', 'Panel digital', 'Control de tracción', 'Transmisión automática']", Valor=63578.5, km_media=1780.5416666666667),
#  Pandas(Index='Hilux', Motor='Motor 5.0 V8 Bi-Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['4 X 4', 'Piloto automático', 'Techo panorámico', 'Central multimedia', 'Ventanas eléctricas', 'Frenos ABS', 'Panel digital', 'Llantas de aleación']", Valor=64507.72, km_media=0.0),
#  Pandas(Index='Grand Siena', Motor='Motor Diesel V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Asientos de cuero', 'Panel digital', 'Sensor de estacionamiento', 'Sensor crepuscular', 'Control de tracción', 'Aire condicionado', 'Cerraduras electricas', '4 X 4']", Valor=115075.59, km_media=0.0),
#  Pandas(Index='Symbol', Motor='Motor Diesel', Año=2016, Kilometraje=117714.0, Cero_km=False, Accesorios="['4 X 4', 'Piloto automático', 'Sensor crepuscular', 'Cámara de estacionamiento', 'Ventanas eléctricas', 'Llantas de aleación', 'Central multimedia', 'Control de tracción']", Valor=133030.6, km_media=39238.0),
#  Pandas(Index='Aston Martin V12 GT Zagato', Motor='Motor 4.0 Turbo', Año=2011, Kilometraje=113885.0, Cero_km=False, Accesorios="['Central multimedia', 'Piloto automático', 'Sensor de lluvia', 'Control de estabilidad', 'Control de tracción', 'Aire condicionado', 'Ventanas eléctricas', 'Techo panorámico']", Valor=141591.86, km_media=14235.625),
#  Pandas(Index='Fusion', Motor='Motor 1.8 16v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Control de tracción', 'Transmisión automática', 'Frenos ABS', 'Sensor de lluvia', 'Cerraduras electricas', 'Cámara de estacionamiento', 'Aire condicionado', 'Sensor crepuscular']", Valor=100380.28, km_media=0.0),
#  Pandas(Index='A4 Sedan', Motor='Motor Diesel', Año=2002, Kilometraje=30511.0, Cero_km=False, Accesorios="['Cámara de estacionamiento', '4 X 4', 'Cerraduras electricas', 'Aire condicionado', 'Techo panorámico', 'Ventanas eléctricas', 'Frenos ABS', 'Central multimedia']", Valor=96369.04, km_media=1794.764705882353),
#  Pandas(Index='Xsara Picasso', Motor='Motor 2.0 16v', Año=2013, Kilometraje=74867.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Techo panorámico', 'Central multimedia', 'Ventanas eléctricas', 'Llantas de aleación', 'Panel digital', 'Sensor crepuscular', 'Piloto automático']", Valor=142603.84, km_media=12477.833333333334),
#  Pandas(Index='207 SW', Motor='Motor 3.0 32v', Año=2017, Kilometraje=119760.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Cerraduras electricas', 'Cámara de estacionamiento', 'Asientos de cuero', 'Sensor de estacionamiento', 'Transmisión automática', 'Piloto automático', 'Sensor de lluvia']", Valor=117709.67, km_media=59880.0),
#  Pandas(Index='Star', Motor='Motor V6', Año=2016, Kilometraje=8356.0, Cero_km=False, Accesorios="['Cámara de estacionamiento', '4 X 4', 'Central multimedia', 'Ventanas eléctricas', 'Sensor crepuscular', 'Sensor de estacionamiento', 'Techo panorámico', 'Piloto automático']", Valor=102241.54, km_media=2785.3333333333335),
#  Pandas(Index='Doblò Cargo', Motor='Motor 3.0 32v', Año=2008, Kilometraje=64247.0, Cero_km=False, Accesorios="['Frenos ABS', 'Techo panorámico', 'Ventanas eléctricas', 'Piloto automático', 'Cámara de estacionamiento', 'Aire condicionado', 'Control de tracción', '4 X 4']", Valor=96065.38, km_media=5840.636363636364),
#  Pandas(Index='Cadillac CTS', Motor='Motor 1.8 16v', Año=2018, Kilometraje=88661.0, Cero_km=False, Accesorios="['Cerraduras electricas', 'Sensor de lluvia', 'Frenos ABS', 'Transmisión automática', 'Sensor de estacionamiento', '4 X 4', 'Aire condicionado', 'Techo panorámico']", Valor=53894.61, km_media=88661.0),
#  Pandas(Index='Cayenne', Motor='Motor 1.0 8v', Año=2003, Kilometraje=4539.0, Cero_km=False, Accesorios="['Control de tracción', 'Piloto automático', 'Cerraduras electricas', 'Asientos de cuero', 'Sensor de lluvia', '4 X 4', 'Control de estabilidad', 'Llantas de aleación']", Valor=123911.78, km_media=283.6875),
#  Pandas(Index='Fox', Motor='Motor 4.0 Turbo', Año=2003, Kilometraje=110116.0, Cero_km=False, Accesorios="['Piloto automático', 'Transmisión automática', 'Cerraduras electricas', 'Sensor de estacionamiento', 'Techo panorámico', 'Central multimedia', 'Aire condicionado', 'Llantas de aleación']", Valor=101996.35, km_media=6882.25),
#  Pandas(Index='Tiida Hatch', Motor='Motor Diesel V6', Año=2004, Kilometraje=33215.0, Cero_km=False, Accesorios="['Techo panorámico', 'Cerraduras electricas', 'Sensor de estacionamiento', 'Central multimedia', '4 X 4', 'Sensor de lluvia', 'Aire condicionado', 'Llantas de aleación']", Valor=83431.66, km_media=2214.3333333333335),
#  Pandas(Index='Dodge Charger', Motor='Motor 2.4 Turbo', Año=2010, Kilometraje=92001.0, Cero_km=False, Accesorios="['Ventanas eléctricas', 'Sensor crepuscular', 'Control de estabilidad', 'Techo panorámico', 'Cámara de estacionamiento', 'Piloto automático', 'Sensor de estacionamiento', '4 X 4']", Valor=122975.63, km_media=10222.333333333334),
#  Pandas(Index='Face', Motor='Motor V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Control de estabilidad', 'Ventanas eléctricas', 'Frenos ABS', 'Sensor de lluvia', 'Cámara de estacionamiento', 'Panel digital', 'Aire condicionado', 'Techo panorámico']", Valor=93227.73, km_media=0.0),
#  Pandas(Index='Prius', Motor='Motor 3.0 32v', Año=2006, Kilometraje=81708.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Asientos de cuero', 'Panel digital', 'Cámara de estacionamiento', 'Techo panorámico', 'Ventanas eléctricas', 'Control de tracción', 'Aire condicionado']", Valor=58762.65, km_media=6285.2307692307695),
#  Pandas(Index='Idea', Motor='Motor V6', Año=2001, Kilometraje=70641.0, Cero_km=False, Accesorios="['Central multimedia', 'Piloto automático', 'Cerraduras electricas', 'Asientos de cuero', '4 X 4', 'Control de tracción', 'Transmisión automática', 'Sensor de lluvia']", Valor=139549.67, km_media=3924.5),
#  Pandas(Index='A8', Motor='Motor 2.0 16v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Panel digital', 'Techo panorámico', 'Piloto automático', 'Sensor de lluvia', 'Transmisión automática', 'Frenos ABS', 'Cámara de estacionamiento', 'Sensor crepuscular']", Valor=122016.42, km_media=0.0),
#  Pandas(Index='Série 1 Cabrio', Motor='Motor 3.0 32v', Año=2015, Kilometraje=91277.0, Cero_km=False, Accesorios="['Ventanas eléctricas', 'Cerraduras electricas', 'Control de tracción', 'Transmisión automática', 'Sensor crepuscular', 'Panel digital', 'Asientos de cuero', 'Sensor de lluvia']", Valor=72731.98, km_media=22819.25),
#  Pandas(Index='Edge', Motor='Motor V6', Año=2018, Kilometraje=26544.0, Cero_km=False, Accesorios="['Frenos ABS', 'Control de tracción', 'Sensor crepuscular', 'Cerraduras electricas', 'Transmisión automática', 'Cámara de estacionamiento', 'Sensor de lluvia', 'Techo panorámico']", Valor=88416.54, km_media=26544.0),
#  Pandas(Index='Cadillac ATS sedan', Motor='Motor 1.8 16v', Año=2017, Kilometraje=52596.0, Cero_km=False, Accesorios="['Panel digital', 'Ventanas eléctricas', 'Techo panorámico', 'Central multimedia', 'Cámara de estacionamiento', 'Llantas de aleación', 'Sensor de lluvia', 'Piloto automático']", Valor=73873.42, km_media=26298.0),
#  Pandas(Index='Lamborghini Asterion LPI 910-4', Motor='Motor 5.0 V8 Bi-Turbo', Año=1992, Kilometraje=47503.0, Cero_km=False, Accesorios="['Aire condicionado', 'Panel digital', 'Control de estabilidad', 'Sensor de lluvia', 'Ventanas eléctricas', 'Techo panorámico', 'Transmisión automática', '4 X 4']", Valor=70709.34, km_media=1759.3703703703704),
#  Pandas(Index='Frontier', Motor='Motor V8', Año=2001, Kilometraje=89056.0, Cero_km=False, Accesorios="['Transmisión automática', 'Llantas de aleación', 'Sensor de estacionamiento', 'Asientos de cuero', 'Ventanas eléctricas', 'Cerraduras electricas', 'Aire condicionado', 'Techo panorámico']", Valor=115306.5, km_media=4947.555555555556),
#  Pandas(Index='Série 3 Sedã', Motor='Motor 3.0 32v', Año=1993, Kilometraje=28834.0, Cero_km=False, Accesorios="['Control de tracción', 'Control de estabilidad', '4 X 4', 'Llantas de aleación', 'Cerraduras electricas', 'Techo panorámico', 'Sensor de lluvia', 'Sensor de estacionamiento']", Valor=55924.63, km_media=1109.0),
#  Pandas(Index='Lamborghini LM002', Motor='Motor 1.8 16v', Año=1995, Kilometraje=110564.0, Cero_km=False, Accesorios="['Asientos de cuero', 'Frenos ABS', 'Central multimedia', 'Control de estabilidad', 'Control de tracción', 'Llantas de aleación', 'Cerraduras electricas', 'Sensor crepuscular']", Valor=85052.26, km_media=4606.833333333333),
#  Pandas(Index='Cadillac XLR', Motor='Motor Diesel V8', Año=2003, Kilometraje=56638.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Techo panorámico', 'Sensor de estacionamiento', 'Asientos de cuero', 'Transmisión automática', 'Cámara de estacionamiento', 'Frenos ABS', 'Llantas de aleación']", Valor=56646.34, km_media=3539.875),
#  Pandas(Index='A4 Avant', Motor='Motor Diesel', Año=2014, Kilometraje=17357.0, Cero_km=False, Accesorios="['Techo panorámico', '4 X 4', 'Asientos de cuero', 'Aire condicionado', 'Llantas de aleación', 'Frenos ABS', 'Control de estabilidad', 'Control de tracción']", Valor=138946.88, km_media=3471.4),
#  Pandas(Index='EcoSport', Motor='Motor 4.0 Turbo', Año=2008, Kilometraje=74015.0, Cero_km=False, Accesorios="['Piloto automático', 'Sensor de estacionamiento', 'Cerraduras electricas', 'Control de estabilidad', 'Sensor crepuscular', 'Techo panorámico', 'Llantas de aleación', 'Aire condicionado']", Valor=108256.72, km_media=6728.636363636364),
#  Pandas(Index='J3', Motor='Motor 1.8 16v', Año=2013, Kilometraje=15196.0, Cero_km=False, Accesorios="['Control de estabilidad', '4 X 4', 'Cámara de estacionamiento', 'Techo panorámico', 'Panel digital', 'Asientos de cuero', 'Sensor de estacionamiento', 'Piloto automático']", Valor=58979.3, km_media=2532.6666666666665),
#  Pandas(Index='Q3', Motor='Motor 3.0 32v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Control de estabilidad', 'Asientos de cuero', 'Panel digital', 'Sensor crepuscular', 'Frenos ABS', '4 X 4', 'Control de tracción', 'Sensor de lluvia']", Valor=114727.68, km_media=0.0),
#  Pandas(Index='Aston Martin V8 Vantage', Motor='Motor V8', Año=2017, Kilometraje=10821.0, Cero_km=False, Accesorios="['Techo panorámico', 'Control de tracción', 'Panel digital', '4 X 4', 'Cámara de estacionamiento', 'Piloto automático', 'Control de estabilidad', 'Sensor de lluvia']", Valor=139661.48, km_media=5410.5),
#  Pandas(Index='Z4 Roadster', Motor='Motor 3.0 32v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Central multimedia', 'Transmisión automática', 'Cerraduras electricas', '4 X 4', 'Asientos de cuero', 'Techo panorámico', 'Frenos ABS', 'Sensor crepuscular']", Valor=80382.24, km_media=0.0),
#  Pandas(Index='Lamborghini Ferruccio', Motor='Motor 3.0 32v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Ventanas eléctricas', 'Piloto automático', 'Techo panorámico', 'Sensor crepuscular', 'Sensor de lluvia', 'Aire condicionado', 'Frenos ABS', 'Cámara de estacionamiento']", Valor=149157.17, km_media=0.0),
#  Pandas(Index='Ford Ka+', Motor='Motor 1.8 16v', Año=2006, Kilometraje=9595.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Piloto automático', 'Control de tracción', 'Control de estabilidad', 'Aire condicionado', 'Central multimedia', 'Transmisión automática', 'Asientos de cuero']", Valor=87830.41, km_media=738.0769230769231),
#  Pandas(Index='Silver Shadow', Motor='Motor Diesel', Año=2015, Kilometraje=99052.0, Cero_km=False, Accesorios="['4 X 4', 'Central multimedia', 'Aire condicionado', 'Techo panorámico', 'Cerraduras electricas', 'Control de tracción', 'Panel digital', 'Sensor de lluvia']", Valor=143568.22, km_media=24763.0),
#  Pandas(Index='Classe C 63 AMG Touring', Motor='Motor Diesel V8', Año=2007, Kilometraje=52389.0, Cero_km=False, Accesorios="['Central multimedia', 'Piloto automático', 'Frenos ABS', 'Sensor crepuscular', 'Transmisión automática', 'Asientos de cuero', 'Sensor de lluvia', 'Ventanas eléctricas']", Valor=138171.85, km_media=4365.75),
#  Pandas(Index='Discovery 4', Motor='Motor 4.0 Turbo', Año=2005, Kilometraje=119945.0, Cero_km=False, Accesorios="['Frenos ABS', 'Llantas de aleación', 'Sensor de lluvia', 'Control de estabilidad', 'Ventanas eléctricas', 'Techo panorámico', 'Sensor crepuscular', 'Control de tracción']", Valor=115784.95, km_media=8567.5),
#  Pandas(Index='Veloster', Motor='Motor Diesel V8', Año=2017, Kilometraje=96005.0, Cero_km=False, Accesorios="['Aire condicionado', 'Central multimedia', 'Asientos de cuero', 'Sensor crepuscular', 'Frenos ABS', 'Ventanas eléctricas', 'Cámara de estacionamiento', '4 X 4']", Valor=146508.99, km_media=48002.5),
#  Pandas(Index='Classe C', Motor='Motor Diesel V6', Año=1998, Kilometraje=31639.0, Cero_km=False, Accesorios="['Frenos ABS', 'Sensor de lluvia', 'Central multimedia', 'Transmisión automática', 'Panel digital', 'Control de tracción', 'Asientos de cuero', 'Control de estabilidad']", Valor=137670.23, km_media=1506.6190476190477),
#  Pandas(Index='Camry', Motor='Motor Diesel', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Cerraduras electricas', 'Llantas de aleación', 'Sensor crepuscular', 'Asientos de cuero', 'Panel digital', 'Frenos ABS', 'Aire condicionado', 'Cámara de estacionamiento']", Valor=138597.27, km_media=0.0),
#  Pandas(Index='C5 Tourer', Motor='Motor Diesel V6', Año=1999, Kilometraje=80187.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Sensor de lluvia', 'Panel digital', 'Cámara de estacionamiento', 'Control de tracción', 'Ventanas eléctricas', 'Central multimedia', '4 X 4']", Valor=147627.81, km_media=4009.35),
#  Pandas(Index='R8 GT', Motor='Motor 4.0 Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Llantas de aleación', 'Transmisión automática', 'Sensor crepuscular', 'Sensor de estacionamiento', 'Asientos de cuero', 'Techo panorámico', 'Frenos ABS', 'Cámara de estacionamiento']", Valor=62999.02, km_media=0.0),
#  Pandas(Index='Bongo', Motor='Motor Diesel V8', Año=2009, Kilometraje=58212.0, Cero_km=False, Accesorios="['Ventanas eléctricas', 'Techo panorámico', 'Panel digital', 'Piloto automático', 'Sensor crepuscular', 'Central multimedia', 'Transmisión automática', 'Llantas de aleación']", Valor=91242.44, km_media=5821.2),
#  Pandas(Index='ASX', Motor='Motor Diesel V8', Año=2003, Kilometraje=61672.0, Cero_km=False, Accesorios="['Aire condicionado', 'Sensor crepuscular', 'Llantas de aleación', 'Control de estabilidad', 'Piloto automático', 'Transmisión automática', 'Sensor de estacionamiento', 'Techo panorámico']", Valor=149489.92, km_media=3854.5),
#  Pandas(Index='Cadillac SRX', Motor='Motor 5.0 V8 Bi-Turbo', Año=1994, Kilometraje=32017.0, Cero_km=False, Accesorios="['Panel digital', 'Piloto automático', 'Control de estabilidad', 'Techo panorámico', 'Cerraduras electricas', 'Llantas de aleación', 'Central multimedia', '4 X 4']", Valor=63529.95, km_media=1280.68),
#  Pandas(Index='Classe CL', Motor='Motor V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Central multimedia', 'Transmisión automática', '4 X 4', 'Control de estabilidad', 'Asientos de cuero', 'Aire condicionado', 'Frenos ABS', 'Cámara de estacionamiento']", Valor=58525.41, km_media=0.0),
#  Pandas(Index='500 Abarth', Motor='Motor V6', Año=1994, Kilometraje=56944.0, Cero_km=False, Accesorios="['4 X 4', 'Techo panorámico', 'Control de tracción', 'Control de estabilidad', 'Sensor de lluvia', 'Cerraduras electricas', 'Panel digital', 'Sensor crepuscular']", Valor=90345.05, km_media=2277.76),
#  Pandas(Index='Aston Martin Cygnet', Motor='Motor 5.0 V8 Bi-Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Panel digital', 'Aire condicionado', 'Sensor crepuscular', 'Frenos ABS', 'Sensor de lluvia', 'Cámara de estacionamiento', 'Control de tracción', 'Ventanas eléctricas']", Valor=147770.87, km_media=0.0),
#  Pandas(Index='Cadillac STS', Motor='Motor 4.0 Turbo', Año=2015, Kilometraje=86519.0, Cero_km=False, Accesorios="['Panel digital', 'Asientos de cuero', 'Sensor de estacionamiento', '4 X 4', 'Piloto automático', 'Transmisión automática', 'Control de tracción', 'Cerraduras electricas']", Valor=106617.71, km_media=21629.75),
#  Pandas(Index='Aston Martin DB9', Motor='Motor 1.8 16v', Año=1996, Kilometraje=4821.0, Cero_km=False, Accesorios="['Aire condicionado', 'Ventanas eléctricas', '4 X 4', 'Cámara de estacionamiento', 'Transmisión automática', 'Llantas de aleación', 'Asientos de cuero', 'Panel digital']", Valor=104929.88, km_media=209.6086956521739),
#  Pandas(Index='NX 200t', Motor='Motor 2.4 Turbo', Año=1997, Kilometraje=101025.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Panel digital', 'Asientos de cuero', 'Llantas de aleación', 'Piloto automático', 'Ventanas eléctricas', '4 X 4', 'Control de tracción']", Valor=100712.45, km_media=4592.045454545455),
#  Pandas(Index='Aston Martin One-77', Motor='Motor V6', Año=1993, Kilometraje=30705.0, Cero_km=False, Accesorios="['Sensor de estacionamiento', 'Llantas de aleación', 'Control de estabilidad', 'Asientos de cuero', 'Control de tracción', 'Piloto automático', 'Central multimedia', 'Ventanas eléctricas']", Valor=141982.93, km_media=1180.9615384615386),
#  Pandas(Index='Lamborghini Veneno', Motor='Motor 3.0 32v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['4 X 4', 'Sensor de estacionamiento', 'Transmisión automática', 'Llantas de aleación', 'Techo panorámico', 'Central multimedia', 'Cerraduras electricas', 'Piloto automático']", Valor=104038.79, km_media=0.0),
#  Pandas(Index='Sentra', Motor='Motor 2.0 16v', Año=1992, Kilometraje=32555.0, Cero_km=False, Accesorios="['Piloto automático', 'Sensor crepuscular', 'Cerraduras electricas', 'Aire condicionado', 'Transmisión automática', 'Panel digital', 'Ventanas eléctricas', 'Control de tracción']", Valor=88501.54, km_media=1205.7407407407406),
#  Pandas(Index='Jumper', Motor='Motor 2.4 Turbo', Año=1995, Kilometraje=103389.0, Cero_km=False, Accesorios="['Aire condicionado', 'Llantas de aleación', 'Transmisión automática', 'Asientos de cuero', 'Piloto automático', 'Frenos ABS', 'Panel digital', 'Ventanas eléctricas']", Valor=79782.02, km_media=4307.875),
#  Pandas(Index='i30', Motor='Motor 1.8 16v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Transmisión automática', 'Control de estabilidad', 'Sensor crepuscular', 'Control de tracción', 'Ventanas eléctricas', 'Frenos ABS', 'Central multimedia', 'Asientos de cuero']", Valor=86224.1, km_media=0.0),
#  Pandas(Index='X6', Motor='Motor Diesel V6', Año=1990, Kilometraje=55289.0, Cero_km=False, Accesorios="['Cámara de estacionamiento', 'Cerraduras electricas', 'Central multimedia', 'Piloto automático', 'Control de tracción', 'Asientos de cuero', 'Sensor crepuscular', 'Sensor de estacionamiento']", Valor=103596.18, km_media=1906.5172413793102),
#  Pandas(Index='Voyage', Motor='Motor 5.0 V8 Bi-Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Aire condicionado', 'Sensor de estacionamiento', 'Asientos de cuero', 'Control de estabilidad', 'Sensor crepuscular', '4 X 4', 'Ventanas eléctricas', 'Cerraduras electricas']", Valor=148996.47, km_media=0.0),
#  Pandas(Index='Phantom I Phantom II', Motor='Motor 1.8 16v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Piloto automático', 'Frenos ABS', 'Panel digital', 'Aire condicionado', 'Asientos de cuero', 'Llantas de aleación', 'Transmisión automática', 'Sensor crepuscular']", Valor=60948.01, km_media=0.0),
#  Pandas(Index='Passat Variant', Motor='Motor 1.0 8v', Año=1991, Kilometraje=115930.0, Cero_km=False, Accesorios="['Frenos ABS', 'Llantas de aleación', 'Piloto automático', 'Control de tracción', 'Asientos de cuero', 'Ventanas eléctricas', 'Techo panorámico', 'Panel digital']", Valor=69535.44, km_media=4140.357142857143),
#  Pandas(Index='Clio', Motor='Motor Diesel', Año=1990, Kilometraje=66437.0, Cero_km=False, Accesorios="['4 X 4', 'Transmisión automática', 'Frenos ABS', 'Asientos de cuero', 'Piloto automático', 'Control de estabilidad', 'Sensor de estacionamiento', 'Sensor crepuscular']", Valor=111130.33, km_media=2290.9310344827586),
#  Pandas(Index='Classe G', Motor='Motor Diesel V6', Año=2012, Kilometraje=96800.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Central multimedia', 'Sensor crepuscular', 'Frenos ABS', 'Llantas de aleación', '4 X 4', 'Ventanas eléctricas', 'Techo panorámico']", Valor=65847.69, km_media=13828.57142857143),
#  Pandas(Index='Silver Ghost', Motor='Motor 1.8 16v', Año=2007, Kilometraje=14237.0, Cero_km=False, Accesorios="['Cerraduras electricas', 'Panel digital', 'Cámara de estacionamiento', 'Central multimedia', 'Control de estabilidad', 'Piloto automático', 'Sensor de estacionamiento', '4 X 4']", Valor=78096.06, km_media=1186.4166666666667),
# ...
#  Pandas(Index='XKR', Motor='Motor Diesel', Año=1996, Kilometraje=85127.0, Cero_km=False, Accesorios="['Control de tracción', 'Aire condicionado', 'Cerraduras electricas', 'Asientos de cuero', 'Llantas de aleación', 'Sensor crepuscular', 'Cámara de estacionamiento', 'Sensor de estacionamiento']", Valor=54263.16, km_media=3701.1739130434785),
#  Pandas(Index='X5', Motor='Motor Diesel', Año=2002, Kilometraje=13606.0, Cero_km=False, Accesorios="['Control de tracción', 'Piloto automático', 'Cerraduras electricas', 'Llantas de aleación', 'Ventanas eléctricas', 'Cámara de estacionamiento', 'Transmisión automática', 'Panel digital']", Valor=62041.32, km_media=800.3529411764706),
#  Pandas(Index='Cadillac DTS', Motor='Motor 1.8 16v', Año=2005, Kilometraje=35647.0, Cero_km=False, Accesorios="['Central multimedia', 'Llantas de aleación', 'Transmisión automática', 'Frenos ABS', 'Piloto automático', 'Cerraduras electricas', 'Cámara de estacionamiento', 'Control de estabilidad']", Valor=129296.11, km_media=2546.214285714286),
#  Pandas(Index='Pajero Dakar', Motor='Motor 4.0 Turbo', Año=1995, Kilometraje=95128.0, Cero_km=False, Accesorios="['Piloto automático', 'Sensor de lluvia', 'Control de estabilidad', 'Techo panorámico', 'Ventanas eléctricas', 'Central multimedia', 'Transmisión automática', 'Control de tracción']", Valor=60998.33, km_media=3963.6666666666665),
#  Pandas(Index='Classe A', Motor='Motor 1.0 8v', Año=1999, Kilometraje=14046.0, Cero_km=False, Accesorios="['Control de tracción', 'Central multimedia', 'Sensor de estacionamiento', 'Piloto automático', 'Asientos de cuero', 'Cerraduras electricas', 'Sensor crepuscular', 'Cámara de estacionamiento']", Valor=58008.5, km_media=702.3),
#  Pandas(Index='Ford Focus Fastback', Motor='Motor 4.0 Turbo', Año=2005, Kilometraje=41194.0, Cero_km=False, Accesorios="['Asientos de cuero', 'Cámara de estacionamiento', 'Sensor crepuscular', 'Sensor de estacionamiento', 'Panel digital', 'Piloto automático', 'Cerraduras electricas', 'Ventanas eléctricas']", Valor=82304.19, km_media=2942.4285714285716),
#  Pandas(Index='Partner', Motor='Motor 2.4 Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Central multimedia', 'Control de tracción', 'Cerraduras electricas', 'Frenos ABS', 'Sensor de lluvia', 'Llantas de aleación', 'Panel digital', 'Sensor de estacionamiento']", Valor=114531.74, km_media=0.0),
#  Pandas(Index='R8', Motor='Motor V6', Año=1997, Kilometraje=96100.0, Cero_km=False, Accesorios="['4 X 4', 'Control de estabilidad', 'Cámara de estacionamiento', 'Piloto automático', 'Cerraduras electricas', 'Central multimedia', 'Asientos de cuero', 'Ventanas eléctricas']", Valor=128565.61, km_media=4368.181818181818),
#  Pandas(Index='Aston Martin DBS Volante', Motor='Motor 4.0 Turbo', Año=1990, Kilometraje=103900.0, Cero_km=False, Accesorios="['Central multimedia', 'Control de estabilidad', 'Sensor crepuscular', 'Techo panorámico', 'Transmisión automática', 'Sensor de estacionamiento', 'Sensor de lluvia', 'Cerraduras electricas']", Valor=126488.26, km_media=3582.7586206896553),
#  Pandas(Index='Mohave', Motor='Motor Diesel V6', Año=2001, Kilometraje=43814.0, Cero_km=False, Accesorios="['Cerraduras electricas', 'Central multimedia', 'Panel digital', 'Transmisión automática', 'Control de tracción', 'Aire condicionado', 'Llantas de aleación', 'Sensor crepuscular']", Valor=119074.55, km_media=2434.1111111111113),
#  Pandas(Index='Fusca', Motor='Motor 3.0 32v', Año=2013, Kilometraje=24638.0, Cero_km=False, Accesorios="['Transmisión automática', 'Techo panorámico', 'Sensor de lluvia', 'Frenos ABS', '4 X 4', 'Llantas de aleación', 'Cerraduras electricas', 'Piloto automático']", Valor=130238.04, km_media=4106.333333333333),
#  Pandas(Index='Chana Family', Motor='Motor V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Piloto automático', 'Techo panorámico', 'Sensor de estacionamiento', 'Cámara de estacionamiento', '4 X 4', 'Central multimedia', 'Llantas de aleación', 'Cerraduras electricas']", Valor=115760.17, km_media=0.0),
#  Pandas(Index='XC40', Motor='Motor 2.4 Turbo', Año=2017, Kilometraje=110966.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Central multimedia', 'Ventanas eléctricas', 'Cámara de estacionamiento', 'Sensor de estacionamiento', 'Cerraduras electricas', 'Techo panorámico', 'Panel digital']", Valor=121248.0, km_media=55483.0),
#  Pandas(Index='Phantom I Jonckheere Aerodynamic Coupe', Motor='Motor 1.8 16v', Año=2011, Kilometraje=15987.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Cerraduras electricas', 'Piloto automático', 'Cámara de estacionamiento', 'Central multimedia', 'Ventanas eléctricas', 'Frenos ABS', 'Sensor de lluvia']", Valor=98156.35, km_media=1998.375),
#  Pandas(Index='Boxer', Motor='Motor V6', Año=2005, Kilometraje=53369.0, Cero_km=False, Accesorios="['Cerraduras electricas', 'Piloto automático', 'Ventanas eléctricas', 'Cámara de estacionamiento', 'Sensor crepuscular', 'Sensor de lluvia', 'Central multimedia', '4 X 4']", Valor=112146.8, km_media=3812.0714285714284),
#  Pandas(Index='Chana Cargo', Motor='Motor 2.0 16v', Año=2007, Kilometraje=10077.0, Cero_km=False, Accesorios="['Techo panorámico', '4 X 4', 'Central multimedia', 'Sensor de lluvia', 'Sensor de estacionamiento', 'Aire condicionado', 'Cámara de estacionamiento', 'Piloto automático']", Valor=102729.63, km_media=839.75),
#  Pandas(Index='Dodge Dakota', Motor='Motor Diesel', Año=1993, Kilometraje=71544.0, Cero_km=False, Accesorios="['Control de tracción', 'Sensor de estacionamiento', 'Piloto automático', 'Central multimedia', '4 X 4', 'Panel digital', 'Cámara de estacionamiento', 'Ventanas eléctricas']", Valor=141083.35, km_media=2751.6923076923076),
#  Pandas(Index='X1', Motor='Motor Diesel V8', Año=1991, Kilometraje=107.0, Cero_km=False, Accesorios="['4 X 4', 'Techo panorámico', 'Aire condicionado', 'Llantas de aleación', 'Panel digital', 'Cámara de estacionamiento', 'Control de tracción', 'Piloto automático']", Valor=102968.76, km_media=3.8214285714285716),
#  Pandas(Index='GLA', Motor='Motor 1.0 8v', Año=1991, Kilometraje=8394.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Cámara de estacionamiento', 'Frenos ABS', 'Control de estabilidad', 'Central multimedia', 'Control de tracción', 'Techo panorámico', 'Sensor crepuscular']", Valor=76310.01, km_media=299.7857142857143),
#  Pandas(Index='Range Rover Sport', Motor='Motor 1.0 8v', Año=1997, Kilometraje=41498.0, Cero_km=False, Accesorios="['Sensor de estacionamiento', 'Cámara de estacionamiento', 'Frenos ABS', 'Asientos de cuero', 'Aire condicionado', '4 X 4', 'Panel digital', 'Piloto automático']", Valor=120481.74, km_media=1886.2727272727273),
#  Pandas(Index='DS3', Motor='Motor 1.8 16v', Año=2000, Kilometraje=116002.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Aire condicionado', 'Transmisión automática', 'Frenos ABS', 'Sensor de lluvia', '4 X 4', 'Sensor de estacionamiento', 'Cerraduras electricas']", Valor=54559.18, km_media=6105.368421052632),
#  Pandas(Index='Veracruz', Motor='Motor Diesel V8', Año=2007, Kilometraje=100858.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Cámara de estacionamiento', 'Cerraduras electricas', 'Central multimedia', '4 X 4', 'Techo panorámico', 'Sensor de estacionamiento', 'Piloto automático']", Valor=92957.64, km_media=8404.833333333334),
#  Pandas(Index='Cadillac CTS coupe, sedan, and wagon', Motor='Motor V8', Año=2006, Kilometraje=67475.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Sensor de estacionamiento', 'Control de estabilidad', 'Techo panorámico', 'Sensor crepuscular', 'Asientos de cuero', 'Cerraduras electricas', 'Panel digital']", Valor=127810.06, km_media=5190.384615384615),
#  Pandas(Index='i30 CW', Motor='Motor Diesel', Año=2015, Kilometraje=8497.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Ventanas eléctricas', 'Control de estabilidad', 'Sensor crepuscular', 'Techo panorámico', 'Panel digital', 'Cerraduras electricas', 'Frenos ABS']", Valor=73311.75, km_media=2124.25),
#  Pandas(Index='Phantom III', Motor='Motor Diesel V6', Año=2008, Kilometraje=4420.0, Cero_km=False, Accesorios="['Ventanas eléctricas', 'Asientos de cuero', 'Piloto automático', 'Aire condicionado', 'Cerraduras electricas', 'Panel digital', 'Techo panorámico', 'Control de tracción']", Valor=65138.03, km_media=401.8181818181818),
#  Pandas(Index='A3 Sedan', Motor='Motor V6', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Aire condicionado', 'Sensor de lluvia', 'Cerraduras electricas', 'Ventanas eléctricas', '4 X 4', 'Techo panorámico', 'Cámara de estacionamiento', 'Piloto automático']", Valor=90141.47, km_media=0.0),
#  Pandas(Index='Aston Martin DB9 Volante', Motor='Motor 2.0 16v', Año=1996, Kilometraje=58537.0, Cero_km=False, Accesorios="['Central multimedia', 'Asientos de cuero', 'Cámara de estacionamiento', 'Cerraduras electricas', 'Llantas de aleación', 'Panel digital', 'Techo panorámico', 'Ventanas eléctricas']", Valor=71160.36, km_media=2545.086956521739),
#  Pandas(Index='Série 7 Sedã', Motor='Motor Diesel', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Ventanas eléctricas', 'Cerraduras electricas', 'Llantas de aleación', 'Control de estabilidad', 'Sensor crepuscular', 'Transmisión automática', 'Frenos ABS', 'Aire condicionado']", Valor=67539.79, km_media=0.0),
#  Pandas(Index='Lamborghini Reventón', Motor='Motor 4.0 Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Control de tracción', 'Aire condicionado', 'Central multimedia', 'Asientos de cuero', 'Cámara de estacionamiento', 'Cerraduras electricas', 'Sensor de lluvia', 'Ventanas eléctricas']", Valor=67664.86, km_media=0.0),
#  Pandas(Index='Grand Livina', Motor='Motor 2.0 16v', Año=2014, Kilometraje=112016.0, Cero_km=False, Accesorios="['Control de tracción', 'Techo panorámico', 'Ventanas eléctricas', '4 X 4', 'Transmisión automática', 'Asientos de cuero', 'Panel digital', 'Sensor de lluvia']", Valor=68652.16, km_media=22403.2),
#  Pandas(Index='V60', Motor='Motor Diesel', Año=2004, Kilometraje=91840.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Sensor crepuscular', 'Aire condicionado', 'Sensor de estacionamiento', 'Asientos de cuero', 'Transmisión automática', 'Central multimedia', 'Techo panorámico']", Valor=114728.74, km_media=6122.666666666667),
#  Pandas(Index='Effa Hafei Picape Cabine Dupla', Motor='Motor V6', Año=2008, Kilometraje=112787.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Control de tracción', 'Asientos de cuero', 'Ventanas eléctricas', 'Panel digital', 'Piloto automático', 'Llantas de aleación', 'Techo panorámico']", Valor=141645.08, km_media=10253.363636363636),
#  Pandas(Index='Benni Mini', Motor='Motor V8', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Sensor crepuscular', 'Transmisión automática', 'Cámara de estacionamiento', 'Frenos ABS', 'Sensor de lluvia', 'Control de estabilidad', 'Panel digital', 'Sensor de estacionamiento']", Valor=126247.84, km_media=0.0),
#  Pandas(Index='Uno', Motor='Motor Diesel V6', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Central multimedia', 'Sensor crepuscular', 'Control de estabilidad', 'Aire condicionado', 'Frenos ABS', 'Control de tracción', 'Techo panorámico', 'Transmisión automática']", Valor=128852.21, km_media=0.0),
#  Pandas(Index='L200 Savana', Motor='Motor 2.0 16v', Año=2012, Kilometraje=9293.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Ventanas eléctricas', 'Panel digital', 'Techo panorámico', 'Control de tracción', 'Transmisión automática', 'Central multimedia', 'Sensor de estacionamiento']", Valor=132384.76, km_media=1327.5714285714287),
#  Pandas(Index='Santa Fe', Motor='Motor 3.0 32v', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Cerraduras electricas', 'Aire condicionado', '4 X 4', 'Llantas de aleación', 'Transmisión automática', 'Sensor de estacionamiento', 'Central multimedia', 'Frenos ABS']", Valor=129415.33, km_media=0.0),
#  Pandas(Index='RS5', Motor='Motor V6', Año=1996, Kilometraje=55083.0, Cero_km=False, Accesorios="['Panel digital', 'Transmisión automática', 'Ventanas eléctricas', 'Cámara de estacionamiento', 'Asientos de cuero', 'Control de tracción', 'Aire condicionado', 'Central multimedia']", Valor=89536.82, km_media=2394.913043478261),
#  Pandas(Index='Cerato', Motor='Motor V6', Año=2011, Kilometraje=48796.0, Cero_km=False, Accesorios="['Sensor de estacionamiento', 'Cámara de estacionamiento', 'Frenos ABS', 'Ventanas eléctricas', 'Control de estabilidad', 'Transmisión automática', 'Control de tracción', 'Asientos de cuero']", Valor=87975.3, km_media=6099.5),
#  Pandas(Index='XC60', Motor='Motor 4.0 Turbo', Año=2019, Kilometraje=nan, Cero_km=True, Accesorios="['Panel digital', 'Piloto automático', 'Central multimedia', 'Control de tracción', 'Cerraduras electricas', 'Llantas de aleación', 'Control de estabilidad', '4 X 4']", Valor=77675.79, km_media=0.0),
#  Pandas(Index='LS 460L', Motor='Motor Diesel V8', Año=2010, Kilometraje=89685.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Frenos ABS', 'Control de tracción', 'Transmisión automática', 'Cámara de estacionamiento', '4 X 4', 'Panel digital', 'Cerraduras electricas']", Valor=58881.67, km_media=9965.0),
#  Pandas(Index='Lamborghini Sesto Elemento', Motor='Motor V8', Año=2007, Kilometraje=85384.0, Cero_km=False, Accesorios="['Sensor crepuscular', 'Frenos ABS', 'Aire condicionado', 'Panel digital', 'Cerraduras electricas', 'Asientos de cuero', 'Sensor de estacionamiento', '4 X 4']", Valor=55081.99, km_media=7115.333333333333),
#  Pandas(Index='Lamborghini Huracán', Motor='Motor V8', Año=1994, Kilometraje=98108.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Sensor de estacionamiento', 'Cámara de estacionamiento', 'Asientos de cuero', 'Llantas de aleación', '4 X 4', 'Transmisión automática', 'Ventanas eléctricas']", Valor=118826.44, km_media=3924.32),
#  Pandas(Index='A7', Motor='Motor 1.0 8v', Año=2007, Kilometraje=71280.0, Cero_km=False, Accesorios="['Sensor de lluvia', 'Ventanas eléctricas', 'Sensor crepuscular', '4 X 4', 'Transmisión automática', 'Control de tracción', 'Asientos de cuero', 'Panel digital']", Valor=137627.62, km_media=5940.0),
#  Pandas(Index='Phantom 2013', Motor='Motor V8', Año=2014, Kilometraje=27505.0, Cero_km=False, Accesorios="['Control de estabilidad', 'Piloto automático', 'Transmisión automática', 'Cámara de estacionamiento', 'Control de tracción', 'Techo panorámico', 'Panel digital', 'Aire condicionado']", Valor=51759.58, km_media=5501.0),
#  Pandas(Index='Cadillac Ciel concept', Motor='Motor V8', Año=1991, Kilometraje=29981.0, Cero_km=False, Accesorios="['Asientos de cuero', 'Panel digital', 'Sensor de lluvia', 'Cerraduras electricas', 'Sensor de estacionamiento', 'Ventanas eléctricas', 'Llantas de aleación', 'Piloto automático']", Valor=51667.06, km_media=1070.75),
#  Pandas(Index='Classe GLK', Motor='Motor 5.0 V8 Bi-Turbo', Año=2002, Kilometraje=52637.0, Cero_km=False, Accesorios="['Llantas de aleación', 'Control de tracción', 'Transmisión automática', 'Techo panorámico', 'Aire condicionado', '4 X 4', 'Central multimedia', 'Sensor crepuscular']", Valor=68934.03, km_media=3096.294117647059),
#  Pandas(Index='Aston Martin DB5', Motor='Motor Diesel', Año=1996, Kilometraje=7685.0, Cero_km=False, Accesorios="['Aire condicionado', '4 X 4', 'Transmisión automática', 'Frenos ABS', 'Control de tracción', 'Cámara de estacionamiento', 'Panel digital', 'Central multimedia']", Valor=122110.9, km_media=334.1304347826087),
#  Pandas(Index='Macan', Motor='Motor Diesel V6', Año=1992, Kilometraje=50188.0, Cero_km=False, Accesorios="['Central multimedia', 'Techo panorámico', 'Ventanas eléctricas', 'Control de tracción', 'Llantas de aleación', 'Frenos ABS', 'Cámara de estacionamiento', 'Cerraduras electricas']", Valor=90381.47, km_media=1858.8148148148148)]

# %%
list(dataset.items())
# Out:
# [('Motor',
#   Nombre
#   Jetta Variant                  Motor 4.0 Turbo
#   Passat                            Motor Diesel
#   Crossfox                       Motor Diesel V8
#   DS5                            Motor 2.4 Turbo
#   Aston Martin DB4               Motor 2.4 Turbo
#                                    ...
#   Phantom 2013                          Motor V8
#   Cadillac Ciel concept                 Motor V8
#   Classe GLK               Motor 5.0 V8 Bi-Turbo
#   Aston Martin DB5                  Motor Diesel
#   Macan                          Motor Diesel V6
#   Name: Motor, Length: 258, dtype: object),
#  ('Año',
#   Nombre
#   Jetta Variant            2003
#   Passat                   1991
#   Crossfox                 1990
#   DS5                      2019
#   Aston Martin DB4         2006
#                            ...
#   Phantom 2013             2014
#   Cadillac Ciel concept    1991
#   Classe GLK               2002
#   Aston Martin DB5         1996
#   Macan                    1992
#   Name: Año, Length: 258, dtype: int64),
#  ('Kilometraje',
#   Nombre
#   Jetta Variant            44410.0
#   Passat                    5712.0
#   Crossfox                 37123.0
#   DS5                          NaN
#   Aston Martin DB4         25757.0
#                             ...
#   Phantom 2013             27505.0
#   Cadillac Ciel concept    29981.0
#   Classe GLK               52637.0
#   Aston Martin DB5          7685.0
#   Macan                    50188.0
#   Name: Kilometraje, Length: 258, dtype: float64),
#  ('Cero_km',
#   Nombre
#   Jetta Variant            False
#   Passat                   False
#   Crossfox                 False
#   DS5                       True
#   Aston Martin DB4         False
#                            ...
#   Phantom 2013             False
#   Cadillac Ciel concept    False
#   Classe GLK               False
#   Aston Martin DB5         False
#   Macan                    False
#   Name: Cero_km, Length: 258, dtype: bool),
#  ('Accesorios',
#   Nombre
#   Jetta Variant            ['Llantas de aleación', 'Cerraduras electricas...
#   Passat                   ['Central multimedia', 'Techo panorámico', 'Fr...
#   Crossfox                 ['Piloto automático', 'Control de estabilidad'...
#   DS5                      ['Cerraduras electricas', '4 X 4', 'Ventanas e...
#   Aston Martin DB4         ['Llantas de aleación', '4 X 4', 'Central mult...
#                                                  ...
#   Phantom 2013             ['Control de estabilidad', 'Piloto automático'...
#   Cadillac Ciel concept    ['Asientos de cuero', 'Panel digital', 'Sensor...
#   Classe GLK               ['Llantas de aleación', 'Control de tracción',...
#   Aston Martin DB5         ['Aire condicionado', '4 X 4', 'Transmisión au...
#   Macan                    ['Central multimedia', 'Techo panorámico', 'Ve...
#   Name: Accesorios, Length: 258, dtype: object),
#  ('Valor',
#   Nombre
#   Jetta Variant             88078.64
#   Passat                   106161.94
#   Crossfox                  72832.16
#   DS5                      124549.07
#   Aston Martin DB4          92612.10
#                              ...
#   Phantom 2013              51759.58
#   Cadillac Ciel concept     51667.06
#   Classe GLK                68934.03
#   Aston Martin DB5         122110.90
#   Macan                     90381.47
#   Name: Valor, Length: 258, dtype: float64),
#  ('km_media',
#   Nombre
#   Jetta Variant            2775.625000
#   Passat                    204.000000
#   Crossfox                 1280.103448
#   DS5                         0.000000
#   Aston Martin DB4         1981.307692
#                               ...
#   Phantom 2013             5501.000000
#   Cadillac Ciel concept    1070.750000
#   Classe GLK               3096.294118
#   Aston Martin DB5          334.130435
#   Macan                    1858.814815
#   Name: km_media, Length: 258, dtype: float64)]

# %% [markdown]
# # 5.5 Tratamiento de datos

# %%
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios  \
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...
# Crossfox          ['Piloto automático', 'Control de estabilidad'...
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...
#
#                       Valor     km_media
# Nombre
# Jetta Variant      88078.64  2775.625000
# Passat            106161.94   204.000000
# Crossfox           72832.16  1280.103448
# DS5               124549.07     0.000000
# Aston Martin DB4   92612.10  1981.307692

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Motor        258 non-null    object
#  1   Año          258 non-null    int64
#  2   Kilometraje  197 non-null    float64
#  3   Cero_km      258 non-null    bool
#  4   Accesorios   258 non-null    object
#  5   Valor        258 non-null    float64
#  6   km_media     258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 22.5+ KB

# %%
dataset.Kilometraje.isna()
# Out:
# Nombre
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Kilometraje, Length: 258, dtype: bool

# %%
dataset[dataset.Kilometraje.isna()]
# Out:
#                                 Motor   Año  Kilometraje  Cero_km  \
# Nombre
# DS5                   Motor 2.4 Turbo  2019          NaN     True
# A5                    Motor 4.0 Turbo  2019          NaN     True
# J5                           Motor V6  2019          NaN     True
# A3                       Motor 1.0 8v  2019          NaN     True
# Série 1 M                    Motor V8  2019          NaN     True
# ...                               ...   ...          ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019          NaN     True
# Benni Mini                   Motor V8  2019          NaN     True
# Uno                   Motor Diesel V6  2019          NaN     True
# Santa Fe                Motor 3.0 32v  2019          NaN     True
# XC60                  Motor 4.0 Turbo  2019          NaN     True
#
#                                                              Accesorios  \
# Nombre
# DS5                   ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# A5                    ['Transmisión automática', 'Cámara de estacion...
# J5                    ['Sensor crepuscular', 'Panel digital', 'Llant...
# A3                    ['4 X 4', 'Piloto automático', 'Central multim...
# Série 1 M             ['Control de estabilidad', 'Central multimedia...
# ...                                                                 ...
# Lamborghini Reventón  ['Control de tracción', 'Aire condicionado', '...
# Benni Mini            ['Sensor crepuscular', 'Transmisión automática...
# Uno                   ['Central multimedia', 'Sensor crepuscular', '...
# Santa Fe              ['Cerraduras electricas', 'Aire condicionado',...
# XC60                  ['Panel digital', 'Piloto automático', 'Centra...
#
#                           Valor  km_media
# Nombre
# DS5                   124549.07       0.0
# A5                     56445.20       0.0
# J5                     53183.38       0.0
# A3                     88552.39       0.0
# Série 1 M              94564.40       0.0
# ...                         ...       ...
# Lamborghini Reventón   67664.86       0.0
# Benni Mini            126247.84       0.0
# Uno                   128852.21       0.0
# Santa Fe              129415.33       0.0
# XC60                   77675.79       0.0
#
# [61 rows x 7 columns]

# %%
dataset.fillna(0)
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          0.0     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# Nombre
# Jetta Variant          ['Llantas de aleación', 'Cerraduras electricas...
# Passat                 ['Central multimedia', 'Techo panorámico', 'Fr...
# Crossfox               ['Piloto automático', 'Control de estabilidad'...
# DS5                    ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# Aston Martin DB4       ['Llantas de aleación', '4 X 4', 'Central mult...
# ...                                                                  ...
# Phantom 2013           ['Control de estabilidad', 'Piloto automático'...
# Cadillac Ciel concept  ['Asientos de cuero', 'Panel digital', 'Sensor...
# Classe GLK             ['Llantas de aleación', 'Control de tracción',...
# Aston Martin DB5       ['Aire condicionado', '4 X 4', 'Transmisión au...
# Macan                  ['Central multimedia', 'Techo panorámico', 'Ve...
#
#                            Valor     km_media
# Nombre
# Jetta Variant           88078.64  2775.625000
# Passat                 106161.94   204.000000
# Crossfox                72832.16  1280.103448
# DS5                    124549.07     0.000000
# Aston Martin DB4        92612.10  1981.307692
# ...                          ...          ...
# Phantom 2013            51759.58  5501.000000
# Cadillac Ciel concept   51667.06  1070.750000
# Classe GLK              68934.03  3096.294118
# Aston Martin DB5       122110.90   334.130435
# Macan                   90381.47  1858.814815
#
# [258 rows x 7 columns]

# %%
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# Nombre
# Jetta Variant          ['Llantas de aleación', 'Cerraduras electricas...
# Passat                 ['Central multimedia', 'Techo panorámico', 'Fr...
# Crossfox               ['Piloto automático', 'Control de estabilidad'...
# DS5                    ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# Aston Martin DB4       ['Llantas de aleación', '4 X 4', 'Central mult...
# ...                                                                  ...
# Phantom 2013           ['Control de estabilidad', 'Piloto automático'...
# Cadillac Ciel concept  ['Asientos de cuero', 'Panel digital', 'Sensor...
# Classe GLK             ['Llantas de aleación', 'Control de tracción',...
# Aston Martin DB5       ['Aire condicionado', '4 X 4', 'Transmisión au...
# Macan                  ['Central multimedia', 'Techo panorámico', 'Ve...
#
#                            Valor     km_media
# Nombre
# Jetta Variant           88078.64  2775.625000
# Passat                 106161.94   204.000000
# Crossfox                72832.16  1280.103448
# DS5                    124549.07     0.000000
# Aston Martin DB4        92612.10  1981.307692
# ...                          ...          ...
# Phantom 2013            51759.58  5501.000000
# Cadillac Ciel concept   51667.06  1070.750000
# Classe GLK              68934.03  3096.294118
# Aston Martin DB5       122110.90   334.130435
# Macan                   90381.47  1858.814815
#
# [258 rows x 7 columns]

# %%
dataset.fillna(0, inplace = True) #modifica el dataset y sustituye el NaN por 0 en este caso porque son todos los autos con 0km los que tienen NaN em kilometraje

# %%
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          0.0     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# Nombre
# Jetta Variant          ['Llantas de aleación', 'Cerraduras electricas...
# Passat                 ['Central multimedia', 'Techo panorámico', 'Fr...
# Crossfox               ['Piloto automático', 'Control de estabilidad'...
# DS5                    ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# Aston Martin DB4       ['Llantas de aleación', '4 X 4', 'Central mult...
# ...                                                                  ...
# Phantom 2013           ['Control de estabilidad', 'Piloto automático'...
# Cadillac Ciel concept  ['Asientos de cuero', 'Panel digital', 'Sensor...
# Classe GLK             ['Llantas de aleación', 'Control de tracción',...
# Aston Martin DB5       ['Aire condicionado', '4 X 4', 'Transmisión au...
# Macan                  ['Central multimedia', 'Techo panorámico', 'Ve...
#
#                            Valor     km_media
# Nombre
# Jetta Variant           88078.64  2775.625000
# Passat                 106161.94   204.000000
# Crossfox                72832.16  1280.103448
# DS5                    124549.07     0.000000
# Aston Martin DB4        92612.10  1981.307692
# ...                          ...          ...
# Phantom 2013            51759.58  5501.000000
# Cadillac Ciel concept   51667.06  1070.750000
# Classe GLK              68934.03  3096.294118
# Aston Martin DB5       122110.90   334.130435
# Macan                   90381.47  1858.814815
#
# [258 rows x 7 columns]

# %%
dataset.query('Cero_km == True')
# Out:
#                                 Motor   Año  Kilometraje  Cero_km  \
# Nombre
# DS5                   Motor 2.4 Turbo  2019          0.0     True
# A5                    Motor 4.0 Turbo  2019          0.0     True
# J5                           Motor V6  2019          0.0     True
# A3                       Motor 1.0 8v  2019          0.0     True
# Série 1 M                    Motor V8  2019          0.0     True
# ...                               ...   ...          ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019          0.0     True
# Benni Mini                   Motor V8  2019          0.0     True
# Uno                   Motor Diesel V6  2019          0.0     True
# Santa Fe                Motor 3.0 32v  2019          0.0     True
# XC60                  Motor 4.0 Turbo  2019          0.0     True
#
#                                                              Accesorios  \
# Nombre
# DS5                   ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# A5                    ['Transmisión automática', 'Cámara de estacion...
# J5                    ['Sensor crepuscular', 'Panel digital', 'Llant...
# A3                    ['4 X 4', 'Piloto automático', 'Central multim...
# Série 1 M             ['Control de estabilidad', 'Central multimedia...
# ...                                                                 ...
# Lamborghini Reventón  ['Control de tracción', 'Aire condicionado', '...
# Benni Mini            ['Sensor crepuscular', 'Transmisión automática...
# Uno                   ['Central multimedia', 'Sensor crepuscular', '...
# Santa Fe              ['Cerraduras electricas', 'Aire condicionado',...
# XC60                  ['Panel digital', 'Piloto automático', 'Centra...
#
#                           Valor  km_media
# Nombre
# DS5                   124549.07       0.0
# A5                     56445.20       0.0
# J5                     53183.38       0.0
# A3                     88552.39       0.0
# Série 1 M              94564.40       0.0
# ...                         ...       ...
# Lamborghini Reventón   67664.86       0.0
# Benni Mini            126247.84       0.0
# Uno                   128852.21       0.0
# Santa Fe              129415.33       0.0
# XC60                   77675.79       0.0
#
# [61 rows x 7 columns]

# %%
dataset = pd.read_csv('db.csv', sep = ';')

# %%
dataset
# Out:
#                     Nombre                  Motor   Año  Kilometraje  Cero_km  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003      44410.0    False
# 1                   Passat           Motor Diesel  1991       5712.0    False
# 2                 Crossfox        Motor Diesel V8  1990      37123.0    False
# 3                      DS5        Motor 2.4 Turbo  2019          NaN     True
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006      25757.0    False
# ..                     ...                    ...   ...          ...      ...
# 253           Phantom 2013               Motor V8  2014      27505.0    False
# 254  Cadillac Ciel concept               Motor V8  1991      29981.0    False
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# 256       Aston Martin DB5           Motor Diesel  1996       7685.0    False
# 257                  Macan        Motor Diesel V6  1992      50188.0    False
#
#                                             Accesorios      Valor
# 0    ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# 1    ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# 2    ['Piloto automático', 'Control de estabilidad'...   72832.16
# 3    ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# 4    ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10
# ..                                                 ...        ...
# 253  ['Control de estabilidad', 'Piloto automático'...   51759.58
# 254  ['Asientos de cuero', 'Panel digital', 'Sensor...   51667.06
# 255  ['Llantas de aleación', 'Control de tracción',...   68934.03
# 256  ['Aire condicionado', '4 X 4', 'Transmisión au...  122110.90
# 257  ['Central multimedia', 'Techo panorámico', 'Ve...   90381.47
#
# [258 rows x 7 columns]

# %%
dataset.dropna(subset = ['Kilometraje'], inplace = True) #elimino las filas donde el valor de kilometraje en NaN, con el inplace me aseguro de eliminarlos del dataset y no solo de la visualizacion como ocurriria si no lo pongo

# %%
dataset
# Out:
#                     Nombre                  Motor   Año  Kilometraje  Cero_km  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003      44410.0    False
# 1                   Passat           Motor Diesel  1991       5712.0    False
# 2                 Crossfox        Motor Diesel V8  1990      37123.0    False
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006      25757.0    False
# 5            Palio Weekend          Motor 1.8 16v  2012      10728.0    False
# ..                     ...                    ...   ...          ...      ...
# 253           Phantom 2013               Motor V8  2014      27505.0    False
# 254  Cadillac Ciel concept               Motor V8  1991      29981.0    False
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# 256       Aston Martin DB5           Motor Diesel  1996       7685.0    False
# 257                  Macan        Motor Diesel V6  1992      50188.0    False
#
#                                             Accesorios      Valor
# 0    ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# 1    ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# 2    ['Piloto automático', 'Control de estabilidad'...   72832.16
# 4    ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10
# 5    ['Sensor de estacionamiento', 'Techo panorámic...   97497.73
# ..                                                 ...        ...
# 253  ['Control de estabilidad', 'Piloto automático'...   51759.58
# 254  ['Asientos de cuero', 'Panel digital', 'Sensor...   51667.06
# 255  ['Llantas de aleación', 'Control de tracción',...   68934.03
# 256  ['Aire condicionado', '4 X 4', 'Transmisión au...  122110.90
# 257  ['Central multimedia', 'Techo panorámico', 'Ve...   90381.47
#
# [197 rows x 7 columns]
